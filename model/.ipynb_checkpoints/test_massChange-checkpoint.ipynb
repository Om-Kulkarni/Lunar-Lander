# %% [markdown]
# The plan for this test run is to give an upward thrust of 100N (main thruster) to the LunarModule till the fuel reserves deplete. This will check if we are successfully altering the mass of the Lunar Module.

# %%
import pybullet as p
import pybullet_data
from pybullet_object_models import ycb_objects
import numpy as np
import time
import math as m
import os, inspect
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d5343cf487d7> in <module>
#       1 import pybullet as p
#       2 import pybullet_data
# ----> 3 from pybullet_object_models import ycb_objects
#       4 import numpy as np
#       5 import time
#
# ModuleNotFoundError: No module named 'pybullet_object_models'

# %%
# Scaling factors for force and torque
ALPHA = 100
BETA = 50

DURATION = 1000

# %%
# Fixed Thrust values
mainThrust = 100
sideThrust = 2.5

# mass lost by main theuster per time step of 50ms
dm = 0.25

# %%
p.disconnect()

# %%
# ------------------------ #
# --- Setup simulation --- #
# ------------------------ #

# Create pybullet GUI
physics_client_id = p.connect(p.GUI)
p.resetDebugVisualizerCamera(1.8, 120, -50, [0.0, -0.0, -0.0])
p.resetSimulation()
p.setPhysicsEngineParameter(numSolverIterations=150)
sim_timestep = 1.0/240
p.setTimeStep(sim_timestep)
p.setRealTimeSimulation(0)

p.loadURDF(os.path.join(pybullet_data.getDataPath(), "plane.urdf"))

p.setGravity(0, 0, -1.62)

urdf_path = r"Lunar_Lander.urdf"
landerId = p.loadURDF(urdf_path, basePosition=[0, 0, 0.5])

# %%
sphereId = p.loadURDF(os.path.join(pybullet_data.getDataPath(), "sphere2red.urdf"), [3, 4, 2])

# %%
# we have assume mass of fuel to be 50% the mass of the lander

mass_fuel_i = p.getDynamicsInfo(landerId, -1)[0] / 2
mass_fuel_i
# Out:
# 25.0

# %%
for i in range(DURATION):

    p.stepSimulation()
    time.sleep(0.05)

    landerPos, landerOrn = p.getBasePositionAndOrientation(landerId)
    spherePos, sphereOrn = p.getBasePositionAndOrientation(sphereId)
    
    # We apply force till the fuel depletes
    if ((p.getDynamicsInfo(landerId, -1)[0] -25) > 0):
        
        force = (np.array([0, 0, 100]))
        p.applyExternalForce(objectUniqueId=landerId, linkIndex=-1,
                             forceObj=force, posObj=landerPos, flags=p.WORLD_FRAME)
        
        p.applyExternalForce(objectUniqueId=sphereId, linkIndex=-1,
                             forceObj=force, posObj=spherePos, flags=p.WORLD_FRAME)
        
        # change the mass of the lunarModule by dm
        currMass = p.getDynamicsInfo(landerId, -1)[0] - dm
        p.changeDynamics(landerId, -1, mass =  currMass)
    
    print('Timestep = {}'.format(i))
    print('Lander Position = {}'.format(landerPos))
    print('Current Fuel Mass = {}'.format(currMass - 25))
    
    print('\n')
# Out:
# Timestep = 0
# Lander Position = (2.3615370843655693e-08, -0.0003526771202099528, -0.004160140377265782)
# Current Fuel Mass = 0.0
#
#
# Timestep = 1
# Lander Position = (1.1799422351216005e-08, -0.00035267719041271513, -0.004160146788473688)
# Current Fuel Mass = 0.0
#
#
# Timestep = 2
# Lander Position = (-1.171250939958907e-08, -0.00035267739754541225, -0.004160165704510872)
# Current Fuel Mass = 0.0
#
#
# Timestep = 3
# Lander Position = (-2.3562591767818376e-08, -0.0003526771894561074, -0.004160146701122503)
# Current Fuel Mass = 0.0
#
#
# Timestep = 4
# Lander Position = (-2.3712768733693567e-08, -0.00035267711922862087, -0.004160140287747051)
# Current Fuel Mass = 0.0
#
#
# Timestep = 5
# Lander Position = (-1.216502362961071e-08, -0.00035267718639564265, -0.0041601464217203826)
# Current Fuel Mass = 0.0
#
#
# Timestep = 6
# Lander Position = (1.1078747913111695e-08, -0.00035267739049405807, -0.004160165060661476)
# Current Fuel Mass = 0.0
#
#
# Timestep = 7
# Lander Position = (2.2661078607618908e-08, -0.0003526771865612374, -0.004160146436855586)
# Current Fuel Mass = 0.0
#
#
# Timestep = 8
# Lander Position = (2.2543546119091156e-08, -0.0003526771203990972, -0.004160140394741345)
# Current Fuel Mass = 0.0
#
#
# Timestep = 9
# Lander Position = (1.0728132268264037e-08, -0.0003526771915471775, -0.004160146892275576)
# Current Fuel Mass = 0.0
#
#
# Timestep = 10
# Lander Position = (-1.278326840511618e-08, -0.00035267739954908677, -0.004160165887685255)
# Current Fuel Mass = 0.0
#
#
# Timestep = 11
# Lander Position = (-2.4632708051513228e-08, -0.00035267719034090447, -0.004160146782115897)
# Current Fuel Mass = 0.0
#
#
# Timestep = 12
# Lander Position = (-2.4782246485634077e-08, -0.00035267711908451354, -0.004160140274778023)
# Current Fuel Mass = 0.0
#
#
# Timestep = 13
# Lander Position = (-1.3233866771591425e-08, -0.0003526771853055191, -0.0041601463223612046)
# Current Fuel Mass = 0.0
#
#
# Timestep = 14
# Lander Position = (1.0010535792862158e-08, -0.0003526773885341693, -0.0041601648818791696)
# Current Fuel Mass = 0.0
#
#
# Timestep = 15
# Lander Position = (2.1593608631219728e-08, -0.0003526771857129521, -0.004160146359589963)
# Current Fuel Mass = 0.0
#
#
# Timestep = 16
# Lander Position = (2.1476814102741557e-08, -0.0003526771205729344, -0.004160140410818762)
# Current Fuel Mass = 0.0
#
#
# Timestep = 17
# Lander Position = (9.662134295533808e-09, -0.00035267719266070285, -0.004160146994165161)
# Current Fuel Mass = 0.0
#
#
# Timestep = 18
# Lander Position = (-1.3848535918527775e-08, -0.00035267740152646526, -0.004160166068457969)
# Current Fuel Mass = 0.0
#
#
# Timestep = 19
# Lander Position = (-2.569713428976724e-08, -0.0003526771912087133, -0.004160146861557652)
# Current Fuel Mass = 0.0
#
#
# Timestep = 20
# Lander Position = (-2.584583564728479e-08, -0.00035267711893216015, -0.004160140261055731)
# Current Fuel Mass = 0.0
#
#
# Timestep = 21
# Lander Position = (-1.429662278721054e-08, -0.0003526771842153719, -0.004160146222999628)
# Current Fuel Mass = 0.0
#
#
# Timestep = 22
# Lander Position = (8.948609325105028e-09, -0.00035267738658200054, -0.004160164703801612)
# Current Fuel Mass = 0.0
#
#
# Timestep = 23
# Lander Position = (2.053262191823415e-08, -0.00035267718486385927, -0.004160146282250344)
# Current Fuel Mass = 0.0
#
#
# Timestep = 24
# Lander Position = (2.0416762949234398e-08, -0.00035267712073794045, -0.004160140426089438)
# Current Fuel Mass = 0.0
#
#
# Timestep = 25
# Lander Position = (8.60301477323478e-09, -0.000352677193757836, -0.004160147094557541)
# Current Fuel Mass = 0.0
#
#
# Timestep = 26
# Lander Position = (-1.4906727406380367e-08, -0.0003526774034803188, -0.004160166247082127)
# Current Fuel Mass = 0.0
#
#
# Timestep = 27
# Lander Position = (-2.675428792209938e-08, -0.00035267719206349035, -0.004160146939809138)
# Current Fuel Mass = 0.0
#
#
# Timestep = 28
# Lander Position = (-2.6901955626401402e-08, -0.00035267711877660723, -0.004160140247041068)
# Current Fuel Mass = 0.0
#
#
# Timestep = 29
# Lander Position = (-1.535171304833617e-08, -0.00035267718313124587, -0.00416014612418775)
# Current Fuel Mass = 0.0
#
#
# Timestep = 30
# Lander Position = (7.894545177823519e-09, -0.00035267738464451424, -0.004160164527064664)
# Current Fuel Mass = 0.0
#
#
# Timestep = 31
# Lander Position = (1.9479693015572652e-08, -0.0003526771840189664, -0.0041601462052940335)
# Current Fuel Mass = 0.0
#
#
# Timestep = 32
# Lander Position = (1.9364965091873217e-08, -0.00035267712089732554, -0.004160140440846546)
# Current Fuel Mass = 0.0
#
#
# Timestep = 33
# Lander Position = (7.552344028420092e-09, -0.0003526771948401383, -0.004160147193595306)
# Current Fuel Mass = 0.0
#
#
# Timestep = 34
# Lander Position = (-1.595627464139397e-08, -0.00035267740541069105, -0.004160166423561746)
# Current Fuel Mass = 0.0
#
#
# Timestep = 35
# Lander Position = (-2.780260298403872e-08, -0.00035267719290666403, -0.004160147017000819)
# Current Fuel Mass = 0.0
#
#
# Timestep = 36
# Lander Position = (-2.79490427162361e-08, -0.0003526771186205547, -0.004160140232980638)
# Current Fuel Mass = 0.0
#
#
# Timestep = 37
# Lander Position = (-1.6397576100794763e-08, -0.0003526771820570123, -0.004160146026279098)
# Current Fuel Mass = 0.0
#
#
# Timestep = 38
# Lander Position = (6.84990255739377e-09, -0.000352677382726654, -0.00416016435211981)
# Current Fuel Mass = 0.0
#
#
# Timestep = 39
# Lander Position = (1.8436378722306335e-08, -0.00035267718318144226, -0.004160146129010434)
# Current Fuel Mass = 0.0
#
#
# Timestep = 40
# Lander Position = (1.8322974929525357e-08, -0.0003526771210526272, -0.004160140455230523)
# Current Fuel Mass = 0.0
#
#
# Timestep = 41
# Lander Position = (6.511674066200136e-09, -0.00035267719590764706, -0.004160147291281884)
# Current Fuel Mass = 0.0
#
#
# Timestep = 42
# Lander Position = (-1.6995628006207705e-08, -0.0003526774073162437, -0.00416016659777462)
# Current Fuel Mass = 0.0
#
#
# Timestep = 43
# Lander Position = (-2.8840532406446652e-08, -0.00035267719373837216, -0.004160147093145325)
# Current Fuel Mass = 0.0
#
#
# Timestep = 44
# Lander Position = (-2.8985552389790426e-08, -0.00035267711846549563, -0.004160140219010832)
# Current Fuel Mass = 0.0
#
#
# Timestep = 45
# Lander Position = (-1.7432669954166192e-08, -0.00035267718099540673, -0.004160145929523541)
# Current Fuel Mass = 0.0
#
#
# Timestep = 46
# Lander Position = (5.8162209226695595e-09, -0.00035267738083229894, -0.004160164179321308)
# Current Fuel Mass = 0.0
#
#
# Timestep = 47
# Lander Position = (1.7404215808362e-08, -0.000352677182353498, -0.004160146053601472)
# Current Fuel Mass = 0.0
#
#
# Timestep = 48
# Lander Position = (1.729232654977385e-08, -0.0003526771212045257, -0.0041601404693035)
# Current Fuel Mass = 0.0
#
#
# Timestep = 49
# Lander Position = (5.482536297995607e-09, -0.00035267719695963705, -0.004160147387551045)
# Current Fuel Mass = 0.0
#
#
# Timestep = 50
# Lander Position = (-1.8023258759749e-08, -0.00035267740919495903, -0.004160166769536524)
# Current Fuel Mass = 0.0
#
#
# Timestep = 51
# Lander Position = (-2.986655027600814e-08, -0.0003526771945581047, -0.0041601471681960945)
# Current Fuel Mass = 0.0
#
#
# Timestep = 52
# Lander Position = (-3.000996155545764e-08, -0.0003526771183123066, -0.004160140205211715)
# Current Fuel Mass = 0.0
#
#
# Timestep = 53
# Lander Position = (-1.8455474332893935e-08, -0.00035267717994857885, -0.004160145834117424)
# Current Fuel Mass = 0.0
#
#
# Timestep = 54
# Lander Position = (4.795017738124988e-09, -0.000352677378964767, -0.004160164008972188)
# Current Fuel Mass = 0.0
#
#
# Timestep = 55
# Lander Position = (1.638471877213322e-08, -0.0003526771815368515, -0.004160145979224059)
# Current Fuel Mass = 0.0
#
#
# Timestep = 56
# Lander Position = (1.6274531491357703e-08, -0.00035267712135326774, -0.004160140483088024)
# Current Fuel Mass = 0.0
#
#
# Timestep = 57
# Lander Position = (4.4664393090402845e-09, -0.0003526771979950034, -0.004160147482301946)
# Current Fuel Mass = 0.0
#
#
# Timestep = 58
# Lander Position = (-1.9037661264891544e-08, -0.0003526774110444932, -0.004160166938633436)
# Current Fuel Mass = 0.0
#
#
# Timestep = 59
# Lander Position = (-3.087915405825804e-08, -0.0003526771953650284, -0.004160147242077068)
# Current Fuel Mass = 0.0
#
#
# Timestep = 60
# Lander Position = (-3.102077077540396e-08, -0.0003526771181615394, -0.004160140191633723)
# Current Fuel Mass = 0.0
#
#
# Timestep = 61
# Lander Position = (-1.946449289011517e-08, -0.0003526771789183526, -0.004160145740227336)
# Current Fuel Mass = 0.0
#
#
# Timestep = 62
# Lander Position = (3.78778626518686e-09, -0.0003526773771270496, -0.0041601638413456595)
# Current Fuel Mass = 0.0
#
#
# Timestep = 63
# Lander Position = (1.5379377637492093e-08, -0.00035267718073294464, -0.0041601459060099)
# Current Fuel Mass = 0.0
# Timestep = 64
# Lander Position = (1.527107654696629e-08, -0.00035267712149887284, -0.0041601404965859136)
# Current Fuel Mass = 0.0
#
#
# Timestep = 65
# Lander Position = (3.464866666682972e-09, -0.0003526771990124611, -0.004160147575417246)
# Current Fuel Mass = 0.0
#
#
# Timestep = 66
# Lander Position = (-2.0037355174090397e-08, -0.0003526774128623622, -0.004160167104838565)
# Current Fuel Mass = 0.0
#
#
# Timestep = 67
# Lander Position = (-3.187686677698531e-08, -0.0003526771961581544, -0.004160147314698014)
# Current Fuel Mass = 0.0
#
#
# Timestep = 68
# Lander Position = (-3.201650643862336e-08, -0.000352677118013579, -0.004160140178312059)
# Current Fuel Mass = 0.0
#
#
# Timestep = 69
# Lander Position = (-2.0458255374149483e-08, -0.0003526771779063738, -0.004160145648003614)
# Current Fuel Mass = 0.0
#
#
# Timestep = 70
# Lander Position = (2.7959934014213794e-09, -0.0003526773753219485, -0.004160163676697613)
# Current Fuel Mass = 0.0
#
#
# Timestep = 71
# Lander Position = (1.4389655798701412e-08, -0.0003526771799430718, -0.004160145834077209)
# Current Fuel Mass = 0.0
#
#
# Timestep = 72
# Lander Position = (1.4283421613764136e-08, -0.0003526771216412517, -0.004160140509789011)
# Current Fuel Mass = 0.0
#
#
# Timestep = 73
# Lander Position = (2.4792747768414576e-09, -0.0003526772000106507, -0.004160147666772806)
# Current Fuel Mass = 0.0
#
#
# Timestep = 74
# Lander Position = (-2.1020887567382297e-08, -0.00035267741464604214, -0.0041601672679214075)
# Current Fuel Mass = 0.0
#
#
# Timestep = 75
# Lander Position = (-3.2858239146199404e-08, -0.00035267719693642997, -0.004160147385962758)
# Current Fuel Mass = 0.0
#
#
# Timestep = 76
# Lander Position = (-3.2995722886919355e-08, -0.000352677117868723, -0.004160140165273906)
# Current Fuel Mass = 0.0
#
#
# Timestep = 77
# Lander Position = (-2.1435319749099533e-08, -0.00035267717691417816, -0.004160145557586525)
# Current Fuel Mass = 0.0
#
#
# Timestep = 78
# Lander Position = (1.821077565685334e-09, -0.0003526773735521371, -0.004160163515272191)
# Current Fuel Mass = 0.0
#
#
# Timestep = 79
# Lander Position = (1.3416987911697052e-08, -0.00035267717916843733, -0.004160145763535977)
# Current Fuel Mass = 0.0
#
#
# Timestep = 80
# Lander Position = (1.3312997590918545e-08, -0.000352677121780261, -0.00416014052268425)
# Current Fuel Mass = 0.0
#
#
# Timestep = 81
# Lander Position = (1.5110907876542337e-09, -0.00035267720098819204, -0.004160147756242608)
# Current Fuel Mass = 0.0
#
#
# Timestep = 82
# Lander Position = (-2.1986835042367967e-08, -0.0003526774163930182, -0.004160167427652343)
# Current Fuel Mass = 0.0
#
#
# Timestep = 83
# Lander Position = (-3.382185165419838e-08, -0.0003526771976987813, -0.004160147455773303)
# Current Fuel Mass = 0.0
#
#
# Timestep = 84
# Lander Position = (-3.395700449322033e-08, -0.00035267711772721917, -0.004160140152541926)
# Current Fuel Mass = 0.0
#
#
# Timestep = 85
# Lander Position = (-2.2394274266662095e-08, -0.0003526771759432275, -0.004160145469109572)
# Current Fuel Mass = 0.0
#
#
# Timestep = 86
# Lander Position = (8.64446632682095e-10, -0.00035267737182018865, -0.0041601633573044)
# Current Fuel Mass = 0.0
#
#
# Timestep = 87
# Lander Position = (1.246277783543091e-08, -0.0003526771784101856, -0.004160145694490715)
# Current Fuel Mass = 0.0
#
#
# Timestep = 88
# Lander Position = (1.2361204327626598e-08, -0.00035267712191573274, -0.004160140535256292)
# Current Fuel Mass = 0.0
#
#
# Timestep = 89
# Lander Position = (5.617105441634813e-10, -0.0003526772019437131, -0.004160147843701373)
# Current Fuel Mass = 0.0
#
#
# Timestep = 90
# Lander Position = (-1.1290593234285509e-08, -0.00035267715361827866, -0.004160143430400159)
# Current Fuel Mass = 0.0
#
#
# Timestep = 91
# Lander Position = (-1.1469538607073509e-08, -0.0003526770970087806, -0.004160138260682122)
# Current Fuel Mass = 0.0
#
#
# Timestep = 92
# Lander Position = (4.9501176334361284e-11, -0.00035267717667042983, -0.004160145535680658)
# Current Fuel Mass = 0.0
#
#
# Timestep = 93
# Lander Position = (1.1579379630762227e-08, -0.000352677129893269, -0.004160141263769274)
# Current Fuel Mass = 0.0
#
#
# Timestep = 94
# Lander Position = (1.1436016766810489e-08, -0.00035267707855604505, -0.0041601365755311705)
# Current Fuel Mass = 0.0
#
#
# Timestep = 95
# Lander Position = (-4.052839611072188e-10, -0.0003526771633585059, -0.004160144320008933)
# Current Fuel Mass = 0.0
#
#
# Timestep = 96
# Lander Position = (-6.00782531944519e-10, -0.0003526771156081246, -0.0041601399592654745)
# Current Fuel Mass = 0.0
#
#
# Timestep = 97
# Lander Position = (1.0901745067271026e-08, -0.00035267720339778155, -0.004160147976512106)
# Current Fuel Mass = 0.0
#
#
# Timestep = 98
# Lander Position = (1.075787345257321e-08, -0.0003526771468054409, -0.0041601428083002665)
# Current Fuel Mass = 0.0
#
#
# Timestep = 99
# Lander Position = (-1.0839209750668155e-09, -0.0003526772267651775, -0.004160150110518807)
# Current Fuel Mass = 0.0
#
#
# Timestep = 100
# Lander Position = (-1.2798668478198367e-09, -0.00035267717332508006, -0.004160145230179686)
# Current Fuel Mass = 0.0
#
#
# Timestep = 101
# Lander Position = (1.0222191183797878e-08, -0.0003526772558796743, -0.004160152769336103)
# Current Fuel Mass = 0.0
#
#
# Timestep = 102
# Lander Position = (1.0077936457363315e-08, -0.0003526771957058457, -0.00416014727405832)
# Current Fuel Mass = 0.0
#
#
# Timestep = 103
# Lander Position = (-1.7642265152102e-09, -0.0003526772723709975, -0.004160154275395509)
# Current Fuel Mass = 0.0
#
#
# Timestep = 104
# Lander Position = (-1.9604883679522773e-09, -0.00035267721466525397, -0.004160149005510213)
# Current Fuel Mass = 0.0
#
#
# Timestep = 105
# Lander Position = (9.541237050344464e-09, -0.0003526772932950606, -0.004160156186238429)
# Current Fuel Mass = 0.0
#
#
# Timestep = 106
# Lander Position = (9.396730914039682e-09, -0.00035267723074486156, -0.004160150473948239)
# Current Fuel Mass = 0.0
#
#
# Timestep = 107
# Lander Position = (-2.4456737184120836e-09, -0.00035267730522403005, -0.004160157275647516)
# Current Fuel Mass = 0.0
#
#
# Timestep = 108
# Lander Position = (-2.6421203013208946e-09, -0.00035267724427333466, -0.004160151709427927)
# Current Fuel Mass = 0.0
#
#
# Timestep = 109
# Lander Position = (8.859407782442858e-09, -0.000352677319917521, -0.004160158617497872)
# Current Fuel Mass = 0.0
#
#
# Timestep = 110
# Lander Position = (8.714781692063815e-09, -0.00035267725585370766, -0.004160152766983528)
# Current Fuel Mass = 0.0
#
#
# Timestep = 111
# Lander Position = (-3.127736600934731e-09, -0.00035267732894051575, -0.004160159441522598)
# Current Fuel Mass = 0.0
#
#
# Timestep = 112
# Lander Position = (-3.3242368557631616e-09, -0.0003526772654767329, -0.004160153645803806)
# Current Fuel Mass = 0.0
#
#
# Timestep = 113
# Lander Position = (8.177227832742567e-09, -0.0003526773388087387, -0.004160160342717517)
# Current Fuel Mass = 0.0
#
#
# Timestep = 114
# Lander Position = (8.032612913694467e-09, -0.0003526772738486576, -0.004160154410355922)
# Current Fuel Mass = 0.0
#
#
# Timestep = 115
# Lander Position = (-3.809890395603569e-09, -0.00035267734611095145, -0.004160161009593296)
# Current Fuel Mass = 0.0
#
#
# Timestep = 116
# Lander Position = (-4.0063135690516705e-09, -0.0003526772806591718, -0.004160155032327413)
# Current Fuel Mass = 0.0
#
#
# Timestep = 117
# Lander Position = (7.495220536456418e-09, -0.00035267735216220274, -0.0041601615622136765)
# Current Fuel Mass = 0.0
#
#
# Timestep = 118
# Lander Position = (7.350747496019391e-09, -0.00035267728674725026, -0.004160155588313692)
# Current Fuel Mass = 0.0
#
#
# Timestep = 119
# Lander Position = (-4.491611904334222e-09, -0.0003526773585910013, -0.0041601621493246276)
# Current Fuel Mass = 0.0
#
#
# Timestep = 120
# Lander Position = (-4.687827656933435e-09, -0.0003526772915283267, -0.004160156024949096)
# Current Fuel Mass = 0.0
#
#
# Timestep = 121
# Lander Position = (6.8139076759765915e-09, -0.00035267736154943744, -0.00416016241950264)
# Current Fuel Mass = 0.0
#
#
# Timestep = 122
# Lander Position = (6.669706712767517e-09, -0.0003526772959948215, -0.004160156432849388)
# Current Fuel Mass = 0.0
#
#
# Timestep = 123
# Lander Position = (-5.172379860630045e-09, -0.00035267736770990584, -0.004160162982106728)
# Current Fuel Mass = 0.0
#
#
# Timestep = 124
# Lander Position = (-5.368258372470524e-09, -0.0003526772993075617, -0.004160156735390215)
# Current Fuel Mass = 0.0
#
#
# Timestep = 125
# Lander Position = (6.1338090575345955e-09, -0.00035267736809639947, -0.004160163017410005)
# Current Fuel Mass = 0.0
#
#
# Timestep = 126
# Lander Position = (5.990009768828504e-09, -0.0003526773026267866, -0.004160157038520282)
# Current Fuel Mass = 0.0
#
#
# Timestep = 127
# Lander Position = (-5.851675301156106e-09, -0.00035267737441978275, -0.004160163594889755)
# Current Fuel Mass = 0.0
#
#
# Timestep = 128
# Lander Position = (-6.0470873750598015e-09, -0.0003526773048732843, -0.004160157243686927)
# Current Fuel Mass = 0.0
#
#
# Timestep = 129
# Lander Position = (5.45544209835542e-09, -0.0003526773726098412, -0.004160163429610701)
# Current Fuel Mass = 0.0
# Timestep = 130
# Lander Position = (5.312173387011489e-09, -0.00035267730738489745, -0.0041601574730653484)
# Current Fuel Mass = 0.0
#
#
# Timestep = 131
# Lander Position = (-6.5289819393725565e-09, -0.0003526773794025827, -0.004160164049951334)
# Current Fuel Mass = 0.0
#
#
# Timestep = 132
# Lander Position = (-6.723799101290196e-09, -0.00035267730885334494, -0.004160157607176383)
# Current Fuel Mass = 0.0
#
#
# Timestep = 133
# Lander Position = (4.779321423510824e-09, -0.00035267737566783947, -0.004160163708896272)
# Current Fuel Mass = 0.0
#
#
# Timestep = 134
# Lander Position = (4.636711404297003e-09, -0.0003526773108005293, -0.004160157785011336)
# Current Fuel Mass = 0.0
#
#
# Timestep = 135
# Lander Position = (-7.203786540638247e-09, -0.00035267738314671653, -0.004160164391894508)
# Current Fuel Mass = 0.0
#
#
# Timestep = 136
# Lander Position = (-7.397881138712472e-09, -0.00035267731169753516, -0.004160157866934862)
# Current Fuel Mass = 0.0
#
#
# Timestep = 137
# Lander Position = (4.105958469874692e-09, -0.0003526773776846558, -0.004160163893098245)
# Current Fuel Mass = 0.0
#
#
# Timestep = 138
# Lander Position = (3.96413437560823e-09, -0.0003526773132543503, -0.0041601580091219365)
# Current Fuel Mass = 0.0
#
#
# Timestep = 139
# Lander Position = (-7.875579298577754e-09, -0.00035267738600194625, -0.0041601646526605)
# Current Fuel Mass = 0.0
#
#
# Timestep = 140
# Lander Position = (-8.068824600406278e-09, -0.0003526773137280833, -0.00416015805238916)
# Current Fuel Mass = 0.0
#
#
# Timestep = 141
# Lander Position = (3.4358610953173575e-09, -0.0003526773789571874, -0.004160164009330047)
# Current Fuel Mass = 0.0
#
#
# Timestep = 142
# Lander Position = (3.294949183440271e-09, -0.00035267731501905823, -0.004160158170300696)
# Current Fuel Mass = 0.0
#
#
# Timestep = 143
# Lander Position = (-8.543854209805449e-09, -0.00035267738821870726, -0.004160164855119737)
# Current Fuel Mass = 0.0
#
#
# Timestep = 144
# Lander Position = (-8.736124498219268e-09, -0.0003526773151758361, -0.004160158184620839)
# Current Fuel Mass = 0.0
#
#
# Timestep = 145
# Lander Position = (2.7695331950327286e-09, -0.00035267737969825566, -0.004160164077027101)
# Current Fuel Mass = 0.0
#
#
# Timestep = 146
# Lander Position = (2.629658655072139e-09, -0.00035267731629000506, -0.0041601582863877275)
# Current Fuel Mass = 0.0
#
#
# Timestep = 147
# Lander Position = (-9.208109445520206e-09, -0.0003526773899762808, -0.00416016501564469)
# Current Fuel Mass = 0.0
#
#
# Timestep = 148
# Lander Position = (-9.399280112961667e-09, -0.000352677316206171, -0.0041601582787327155)
# Current Fuel Mass = 0.0
#
#
# Timestep = 149
# Lander Position = (2.1074743234767946e-09, -0.00035267738006044804, -0.004160164110124143)
# Current Fuel Mass = 0.0
#
#
# Timestep = 150
# Lander Position = (1.9687611848426276e-09, -0.00035267731720713504, -0.004160158370163139)
# Current Fuel Mass = 0.0
#
#
# Timestep = 151
# Lander Position = (-9.867847721202726e-09, -0.00035267739140297993, -0.0041601651459532525)
# Current Fuel Mass = 0.0
#
#
# Timestep = 152
# Lander Position = (-1.0057795362397907e-08, -0.0003526773169375709, -0.00416015834554495)
# Current Fuel Mass = 0.0
#
#
# Timestep = 153
# Lander Position = (1.4501793215168924e-09, -0.0003526773801532012, -0.004160164118615207)
# Current Fuel Mass = 0.0
#
#
# Timestep = 154
# Lander Position = (1.3127503625913765e-09, -0.0003526773178706971, -0.004160158430781949)
# Current Fuel Mass = 0.0
#
#
# Timestep = 155
# Lander Position = (-1.0522576661469125e-08, -0.00035267739259060155, -0.0041601652544285585)
# Current Fuel Mass = 0.0
#
#
# Timestep = 156
# Lander Position = (-1.0711179165229178e-08, -0.00035267731745491796, -0.004160158392809186)
# Current Fuel Mass = 0.0
#
#
# Timestep = 157
# Lander Position = (7.981379490323394e-10, -0.0003526773800550348, -0.004160164109670898)
# Current Fuel Mass = 0.0
#
#
# Timestep = 158
# Lander Position = (6.621146069362254e-10, -0.000352677318352503, -0.004160158474802181)
# Current Fuel Mass = 0.0
#
#
# Timestep = 159
# Lander Position = (-1.1171809162206094e-08, -0.00035267739360478643, -0.004160165347065104)
# Current Fuel Mass = 0.0
#
#
# Timestep = 160
# Lander Position = (-1.1358945801425942e-08, -0.00035267731781902525, -0.004160158426079099)
# Current Fuel Mass = 0.0
#
#
# Timestep = 161
# Lander Position = (1.5183452278687752e-10, -0.00035267737982232005, -0.004160164088439204)
# Current Fuel Mass = 0.0
#
#
# Timestep = 162
# Lander Position = (1.167345440523712e-08, -0.00035267731679237925, -0.004160158332299619)
# Current Fuel Mass = 0.0
#
#
# Timestep = 163
# Lander Position = (1.1521899125216225e-08, -0.00035267725051018033, -0.004160152279264142)
# Current Fuel Mass = 0.0
#
#
# Timestep = 164
# Lander Position = (-3.2753291889463626e-10, -0.0003526773215705091, -0.004160158768741285)
# Current Fuel Mass = 0.0
#
#
# Timestep = 165
# Lander Position = (-5.312148892605716e-10, -0.0003526772611404178, -0.004160153250066684)
# Current Fuel Mass = 0.0
#
#
# Timestep = 166
# Lander Position = (1.0963080629031438e-08, -0.00035267733725726224, -0.004160160201292408)
# Current Fuel Mass = 0.0
#
#
# Timestep = 167
# Lander Position = (1.0811027760025981e-08, -0.000352677269992597, -0.0041601540584699104)
# Current Fuel Mass = 0.0
#
#
# Timestep = 168
# Lander Position = (-1.0389037928311046e-09, -0.0003526773401410707, -0.004160160464676083)
# Current Fuel Mass = 0.0
#
#
# Timestep = 169
# Lander Position = (-1.2430200795767404e-09, -0.0003526772775788408, -0.004160154751290984)
# Current Fuel Mass = 0.0
#
#
# Timestep = 170
# Lander Position = (1.0250833004728154e-08, -0.00035267735173363454, -0.004160161523336194)
# Current Fuel Mass = 0.0
#
#
# Timestep = 171
# Lander Position = (1.0098414222030439e-08, -0.0003526772839572751, -0.004160155333786308)
# Current Fuel Mass = 0.0
#
#
# Timestep = 172
# Lander Position = (-1.7518808692867754e-09, -0.00035267735363538933, -0.004160161697033788)
# Current Fuel Mass = 0.0
#
#
# Timestep = 173
# Lander Position = (-1.95629375954503e-09, -0.0003526772893472363, -0.004160155826034425)
# Current Fuel Mass = 0.0
#
#
# Timestep = 174
# Lander Position = (9.537256189300422e-09, -0.00035267736191382554, -0.004160162453040616)
# Current Fuel Mass = 0.0
#
#
# Timestep = 175
# Lander Position = (9.384609256962941e-09, -0.00035267729396911654, -0.004160156248117924)
# Current Fuel Mass = 0.0
#
#
# Timestep = 176
# Lander Position = (-2.4659130020861387e-09, -0.000352677363492627, -0.004160162597242997)
# Current Fuel Mass = 0.0
#
#
# Timestep = 177
# Lander Position = (-2.670484936384916e-09, -0.00035267729777012786, -0.004160156595256546)
# Current Fuel Mass = 0.0
#
#
# Timestep = 178
# Lander Position = (8.8229005664718e-09, -0.0003526773690168894, -0.004160163101733209)
# Current Fuel Mass = 0.0
#
#
# Timestep = 179
# Lander Position = (8.670163007301343e-09, -0.000352677301149154, -0.004160156903840874)
# Current Fuel Mass = 0.0
#
#
# Timestep = 180
# Lander Position = (-3.180449900579123e-09, -0.00035267737074363563, -0.004160163259444089)
# Current Fuel Mass = 0.0
#
#
# Timestep = 181
# Lander Position = (-3.3850435832574376e-09, -0.00035267730379638955, -0.004160157145611422)
# Current Fuel Mass = 0.0
#
#
# Timestep = 182
# Lander Position = (8.10831557316114e-09, -0.00035267737391628067, -0.004160163549180328)
# Current Fuel Mass = 0.0
#
#
# Timestep = 183
# Lander Position = (7.955624568849587e-09, -0.0003526773063004727, -0.004160157374295306)
# Current Fuel Mass = 0.0
#
#
# Timestep = 184
# Lander Position = (-3.894942530466975e-09, -0.00035267737612676154, -0.004160163751064928)
# Current Fuel Mass = 0.0
#
#
# Timestep = 185
# Lander Position = (-4.099421037772202e-09, -0.0003526773081057908, -0.004160157539177569)
# Current Fuel Mass = 0.0
#
#
# Timestep = 186
# Lander Position = (7.394049267118082e-09, -0.00035267737723787584, -0.004160163852538749)
# Current Fuel Mass = 0.0
#
#
# Timestep = 187
# Lander Position = (7.24154155737143e-09, -0.00035267730999838864, -0.0041601577120207196)
# Current Fuel Mass = 0.0
#
#
# Timestep = 188
# Lander Position = (-4.608843517269347e-09, -0.00035267738017080355, -0.004160164120396886)
# Current Fuel Mass = 0.0
#
#
# Timestep = 189
# Lander Position = (-4.813070404145527e-09, -0.0003526773111853128, -0.0041601578204275525)
# Current Fuel Mass = 0.0
#
#
# Timestep = 190
# Lander Position = (6.68064789900588e-09, -0.0003526773794301857, -0.004160164052767694)
# Current Fuel Mass = 0.0
#
#
# Timestep = 191
# Lander Position = (6.528459680255444e-09, -0.00035267731265504435, -0.004160157954655206)
# Current Fuel Mass = 0.0
#
#
# Timestep = 192
# Lander Position = (-5.321607552294336e-09, -0.0003526773832544469, -0.004160164402022561)
# Current Fuel Mass = 0.0
#
#
# Timestep = 193
# Lander Position = (-5.5254469574803416e-09, -0.00035267731338383166, -0.004160158021221737)
# Current Fuel Mass = 0.0
# Timestep = 194
# Lander Position = (5.968655491429572e-09, -0.0003526773808146586, -0.004160164179222699)
# Current Fuel Mass = 0.0
#
#
# Timestep = 195
# Lander Position = (5.816922316053605e-09, -0.00035267731456568825, -0.00416015812916169)
# Current Fuel Mass = 0.0
#
#
# Timestep = 196
# Lander Position = (-6.032691797056549e-09, -0.0003526773856488362, -0.004160164620703592)
# Current Fuel Mass = 0.0
#
#
# Timestep = 197
# Lander Position = (-6.236008546843511e-09, -0.0003526773149512807, -0.0041601581643847295)
# Current Fuel Mass = 0.0
#
#
# Timestep = 198
# Lander Position = (5.258613423426053e-09, -0.0003526773816217134, -0.004160164252946244)
# Current Fuel Mass = 0.0
#
#
# Timestep = 199
# Lander Position = (5.1074700987754765e-09, -0.0003526773159418256, -0.004160158254855406)
# Current Fuel Mass = 0.0
#
#
# Timestep = 200
# Lander Position = (-6.741556287441103e-09, -0.0003526773875480755, -0.004160164794166116)
# Current Fuel Mass = 0.0
#
#
# Timestep = 201
# Lander Position = (-6.9442159983286876e-09, -0.0003526773160667145, -0.004160158266268329)
# Current Fuel Mass = 0.0
#
#
# Timestep = 202
# Lander Position = (4.551060018836844e-09, -0.00035267738201655844, -0.004160164289025581)
# Current Fuel Mass = 0.0
#
#
# Timestep = 203
# Lander Position = (4.400640507006483e-09, -0.0003526773169349718, -0.004160158345573188)
# Current Fuel Mass = 0.0
#
#
# Timestep = 204
# Lander Position = (-7.447664335661573e-09, -0.00035267738909108446, -0.004160164935096629)
# Current Fuel Mass = 0.0
#
#
# Timestep = 205
# Lander Position = (-7.649533515685198e-09, -0.0003526773168584119, -0.004160158338587294)
# Current Fuel Mass = 0.0
#
#
# Timestep = 206
# Lander Position = (3.846530140048009e-09, -0.000352677382117683, -0.004160164298281474)
# Current Fuel Mass = 0.0
#
#
# Timestep = 207
# Lander Position = (3.6969674584324706e-09, -0.000352677317653665, -0.004160158411227051)
# Current Fuel Mass = 0.0
#
#
# Timestep = 208
# Lander Position = (-8.150482929417706e-09, -0.0003526773903772459, -0.0041601650525710495)
# Current Fuel Mass = 0.0
#
#
# Timestep = 209
# Lander Position = (-8.351429078514506e-09, -0.0003526773174182745, -0.004160158389734375)
# Current Fuel Mass = 0.0
#
#
# Timestep = 210
# Lander Position = (3.1455547858522163e-09, -0.00035267738201010446, -0.0041601642884779464)
# Current Fuel Mass = 0.0
#
#
# Timestep = 211
# Lander Position = (2.996980908013807e-09, -0.0003526773181756539, -0.004160158458917235)
# Current Fuel Mass = 0.0
#
#
# Timestep = 212
# Lander Position = (-8.849483128308905e-09, -0.000352677391477624, -0.004160165153079151)
# Current Fuel Mass = 0.0
#
#
# Timestep = 213
# Lander Position = (-9.049374837232717e-09, -0.00035267731781214636, -0.004160158425722621)
# Current Fuel Mass = 0.0
#
#
# Timestep = 214
# Lander Position = (2.4486606944122993e-09, -0.0003526773817548625, -0.004160164265189306)
# Current Fuel Mass = 0.0
#
#
# Timestep = 215
# Lander Position = (2.3012064529322294e-09, -0.0003526773185566331, -0.004160158493729908)
# Current Fuel Mass = 0.0
#
#
# Timestep = 216
# Lander Position = (-9.544140455073881e-09, -0.00035267739244299436, -0.004160165241257909)
# Current Fuel Mass = 0.0
#
#
# Timestep = 217
# Lander Position = (-9.742847503075415e-09, -0.0003526773180871995, -0.004160158450859951)
# Current Fuel Mass = 0.0
#
#
# Timestep = 218
# Lander Position = (1.7563699516222193e-09, -0.0003526773813958146, -0.00416016423242076)
# Current Fuel Mass = 0.0
#
#
# Timestep = 219
# Lander Position = (1.6101649409139471e-09, -0.00035267731883649423, -0.004160158519308114)
# Current Fuel Mass = 0.0
#
#
# Timestep = 220
# Lander Position = (-1.0233935284286121e-08, -0.00035267739330960274, -0.004160165320417383)
# Current Fuel Mass = 0.0
#
#
# Timestep = 221
# Lander Position = (-1.0431328735841352e-08, -0.00035267731827723505, -0.004160158468233146)
# Current Fuel Mass = 0.0
#
#
# Timestep = 222
# Lander Position = (1.069199602869877e-09, -0.0003526773809645105, -0.004160164193053485)
# Current Fuel Mass = 0.0
#
#
# Timestep = 223
# Lander Position = (9.243720838543462e-10, -0.00035267731904381185, -0.004160158538261357)
# Current Fuel Mass = 0.0
#
#
# Timestep = 224
# Lander Position = (-1.0918353225624005e-08, -0.00035267739410328714, -0.004160165392917182)
# Current Fuel Mass = 0.0
#
#
# Timestep = 225
# Lander Position = (-1.111430552536157e-08, -0.0003526773184064715, -0.00416015848005393)
# Current Fuel Mass = 0.0
#
#
# Timestep = 226
# Lander Position = (3.8766127169250413e-10, -0.0003526773804836778, -0.004160164149163035)
# Current Fuel Mass = 0.0
#
#
# Timestep = 227
# Lander Position = (2.4433807750343556e-10, -0.00035267731919905073, -0.004160158552458549)
# Current Fuel Mass = 0.0
#
#
# Timestep = 228
# Lander Position = (-1.1596885502009095e-08, -0.0003526773948424314, -0.004160165460436164)
# Current Fuel Mass = 0.0
#
#
# Timestep = 229
# Lander Position = (-1.1791270568852497e-08, -0.00035267731849226487, -0.004160158487907308)
# Current Fuel Mass = 0.0
#
#
# Timestep = 230
# Lander Position = (-2.877392171818353e-10, -0.0003526773799697258, -0.004160164102247976)
# Current Fuel Mass = 0.0
#
#
# Timestep = 231
# Lander Position = (2.291180169897117e-08, -0.00035267757879388643, -0.0041601822593836536)
# Current Fuel Mass = 0.0
#
#
# Timestep = 232
# Lander Position = (3.444877641457104e-08, -0.00035267734963288647, -0.004160161331728649)
# Current Fuel Mass = 0.0
#
#
# Timestep = 233
# Lander Position = (3.428599372564798e-08, -0.0003526772603003493, -0.004160153173655075)
# Current Fuel Mass = 0.0
#
#
# Timestep = 234
# Lander Position = (2.2425427992801594e-08, -0.00035267731017231174, -0.004160157728206989)
# Current Fuel Mass = 0.0
#
#
# Timestep = 235
# Lander Position = (-1.1310340295194783e-09, -0.0003526774986407012, -0.004160174939778404)
# Current Fuel Mass = 0.0
#
#
# Timestep = 236
# Lander Position = (-1.3026741754160463e-08, -0.0003526772914896303, -0.004160156022143629)
# Current Fuel Mass = 0.0
#
#
# Timestep = 237
# Lander Position = (-1.3222534297670458e-08, -0.00035267722208530037, -0.00416014968395413)
# Current Fuel Mass = 0.0
#
#
# Timestep = 238
# Lander Position = (-1.720394828042718e-09, -0.00035267728996848723, -0.004160155883285999)
# Current Fuel Mass = 0.0
#
#
# Timestep = 239
# Lander Position = (2.1477780354119043e-08, -0.00035267749468464695, -0.004160174578539799)
# Current Fuel Mass = 0.0
#
#
# Timestep = 240
# Lander Position = (3.301351314501572e-08, -0.0003526772735600556, -0.004160154384754328)
# Current Fuel Mass = 0.0
#
#
# Timestep = 241
# Lander Position = (3.28494573971097e-08, -0.00035267719162231803, -0.0041601469019811625)
# Current Fuel Mass = 0.0
#
#
# Timestep = 242
# Lander Position = (2.0987589891383335e-08, -0.00035267724829868475, -0.004160152077934636)
# Current Fuel Mass = 0.0
#
#
# Timestep = 243
# Lander Position = (-2.570200273155321e-09, -0.00035267744302835594, -0.004160169861319796)
# Current Fuel Mass = 0.0
#
#
# Timestep = 244
# Lander Position = (-1.4467063244874361e-08, -0.0003526772390153231, -0.004160151230231372)
# Current Fuel Mass = 0.0
#
#
# Timestep = 245
# Lander Position = (-1.4663997778788598e-08, -0.0003526771724968168, -0.004160145155576593)
# Current Fuel Mass = 0.0
#
#
# Timestep = 246
# Lander Position = (-3.1629881820452535e-09, -0.00035267724303397, -0.004160151597287653)
# Current Fuel Mass = 0.0
#
#
# Timestep = 247
# Lander Position = (2.0034068315254232e-08, -0.0003526774501908051, -0.004160170515458546)
# Current Fuel Mass = 0.0
#
#
# Timestep = 248
# Lander Position = (3.156882063893214e-08, -0.0003526772339389465, -0.00416015076664748)
# Current Fuel Mass = 0.0
#
#
# Timestep = 249
# Lander Position = (3.140376580858093e-08, -0.0003526771564851791, -0.004160143693356913)
# Current Fuel Mass = 0.0
#
#
# Timestep = 250
# Lander Position = (1.954088201952696e-08, -0.0003526772172877188, -0.004160149246125122)
# Current Fuel Mass = 0.0
#
#
# Timestep = 251
# Lander Position = (-4.017940209655422e-09, -0.00035267741581441564, -0.004160167376269837)
# Current Fuel Mass = 0.0
#
#
# Timestep = 252
# Lander Position = (-1.5915671652022384e-08, -0.0003526772126629299, -0.004160148823844842)
# Current Fuel Mass = 0.0
#
#
# Timestep = 253
# Lander Position = (-1.6113470506196178e-08, -0.0003526771469361182, -0.004160142821486608)
# Current Fuel Mass = 0.0
#
#
# Timestep = 254
# Lander Position = (-4.613321491081204e-09, -0.0003526772182008734, -0.0041601493296522735)
# Current Fuel Mass = 0.0
#
#
# Timestep = 255
# Lander Position = (1.8582877903279024e-08, -0.00035267742602634845, -0.004160168308903875)
# Current Fuel Mass = 0.0
#
#
# Timestep = 256
# Lander Position = (3.0116918825145204e-08, -0.0003526772130244557, -0.004160148856881523)
# Current Fuel Mass = 0.0
#
#
# Timestep = 257
# Lander Position = (2.9951140370559126e-08, -0.0003526771385614641, -0.004160142056714006)
# Current Fuel Mass = 0.0
#
#
# Timestep = 258
# Lander Position = (1.8087521634485536e-08, -0.0003526772021161793, -0.004160147860817486)
# Current Fuel Mass = 0.0
# Timestep = 259
# Lander Position = (-5.47204591808605e-09, -0.00035267740317555563, -0.004160166222251853)
# Current Fuel Mass = 0.0
#
#
# Timestep = 260
# Lander Position = (-1.737036382924506e-08, -0.0003526771997169966, -0.004160147641774855)
# Current Fuel Mass = 0.0
#
#
# Timestep = 261
# Lander Position = (-1.7568749705375123e-08, -0.0003526771337069974, -0.004160141613553518)
# Current Fuel Mass = 0.0
#
#
# Timestep = 262
# Lander Position = (-6.069188302341505e-09, -0.0003526772047107026, -0.004160148097885281)
# Current Fuel Mass = 0.0
#
#
# Timestep = 263
# Lander Position = (1.7126422974837295e-08, -0.0003526774122954923, -0.004160167055170627)
# Current Fuel Mass = 0.0
#
#
# Timestep = 264
# Lander Position = (2.8660025297075522e-08, -0.0003526772017104769, -0.004160147823861894)
# Current Fuel Mass = 0.0
#
#
# Timestep = 265
# Lander Position = (2.8493799273723523e-08, -0.0003526771294715711, -0.004160141226802632)
# Current Fuel Mass = 0.0
#
#
# Timestep = 266
# Lander Position = (1.6629724636154892e-08, -0.00035267719507285216, -0.004160147217801899)
# Current Fuel Mass = 0.0
#
#
# Timestep = 267
# Lander Position = (-6.930306446062123e-09, -0.0003526773980154884, -0.004160165751215765)
# Current Fuel Mass = 0.0
#
#
# Timestep = 268
# Lander Position = (-1.8828931543731966e-08, -0.0003526771936509371, -0.004160147087994934)
# Current Fuel Mass = 0.0
#
#
# Timestep = 269
# Lander Position = (-1.9027627599068853e-08, -0.0003526771268069919, -0.004160140983614465)
# Current Fuel Mass = 0.0
#
#
# Timestep = 270
# Lander Position = (-7.528379211700387e-09, -0.00035267719704319396, -0.004160147397860507)
# Current Fuel Mass = 0.0
#
#
# Timestep = 271
# Lander Position = (1.566691647626407e-08, -0.00035267740392160414, -0.004160166290648571)
# Current Fuel Mass = 0.0
#
#
# Timestep = 272
# Lander Position = (2.7200354549322968e-08, -0.00035267719532452204, -0.004160147240883556)
# Current Fuel Mass = 0.0
#
#
# Timestep = 273
# Lander Position = (2.703395695349641e-08, -0.00035267712491482363, -0.004160140810871836)
# Current Fuel Mass = 0.0
#
#
# Timestep = 274
# Lander Position = (1.516970392250195e-08, -0.00035267719219913147, -0.004160146955566787)
# Current Fuel Mass = 0.0
#
#
# Timestep = 275
# Lander Position = (-8.390511792849026e-09, -0.0003526773966903191, -0.004160165630391859)
# Current Fuel Mass = 0.0
#
#
# Timestep = 276
# Lander Position = (-2.0289166660868106e-08, -0.0003526771911143562, -0.004160146856537065)
# Current Fuel Mass = 0.0
#
#
# Timestep = 277
# Lander Position = (-2.0487896753039946e-08, -0.00035267712315572864, -0.004160140650360235)
# Current Fuel Mass = 0.0
#
#
# Timestep = 278
# Lander Position = (-8.988686412657979e-09, -0.00035267719236639595, -0.004160146970955831)
# Current Fuel Mass = 0.0
#
#
# Timestep = 279
# Lander Position = (1.4206567573095862e-08, -0.00035267739830128114, -0.004160165777588518)
# Current Fuel Mass = 0.0
#
#
# Timestep = 280
# Lander Position = (2.5740115971556612e-08, -0.00035267719146947864, -0.004160146889035104)
# Current Fuel Mass = 0.0
#
#
# Timestep = 281
# Lander Position = (2.5573822202963772e-08, -0.0003526771226838982, -0.0041601406073419524)
# Current Fuel Mass = 0.0
#
#
# Timestep = 282
# Lander Position = (1.3709666935315717e-08, -0.00035267719146230133, -0.004160146888478483)
# Current Fuel Mass = 0.0
#
#
# Timestep = 283
# Lander Position = (-9.850456562199967e-09, -0.00035267739732797225, -0.0041601656888174765)
# Current Fuel Mass = 0.0
#
#
# Timestep = 284
# Lander Position = (-2.17488654131567e-08, -0.0003526771903869251, -0.004160146790295749)
# Current Fuel Mass = 0.0
#
#
# Timestep = 285
# Lander Position = (-2.194735442579819e-08, -0.0003526771211724835, -0.004160140469434221)
# Current Fuel Mass = 0.0
#
#
# Timestep = 286
# Lander Position = (-1.0447907635191172e-08, -0.00035267718922802233, -0.004160146684544217)
# Current Fuel Mass = 0.0
#
#
# Timestep = 287
# Lander Position = (1.274757857362526e-08, -0.00035267739410040164, -0.004160165394155158)
# Current Fuel Mass = 0.0
#
#
# Timestep = 288
# Lander Position = (2.4281511217099274e-08, -0.0003526771889159832, -0.004160146656047447)
# Current Fuel Mass = 0.0
#
#
# Timestep = 289
# Lander Position = (2.4115595603561366e-08, -0.00035267712164580966, -0.004160140512745219)
# Current Fuel Mass = 0.0
#
#
# Timestep = 290
# Lander Position = (1.2251812800588194e-08, -0.0003526771918180457, -0.0041601469211668875)
# Current Fuel Mass = 0.0
#
#
# Timestep = 291
# Lander Position = (-1.1307943436404112e-08, -0.0003526773989657101, -0.004160165838572919)
# Current Fuel Mass = 0.0
#
#
# Timestep = 292
# Lander Position = (-2.3205832188144307e-08, -0.0003526771905848922, -0.004160146808564118)
# Current Fuel Mass = 0.0
#
#
# Timestep = 293
# Lander Position = (-2.3403806396753727e-08, -0.00035267712004617127, -0.0041601403667655785)
# Current Fuel Mass = 0.0
#
#
# Timestep = 294
# Lander Position = (-1.1903849762294835e-08, -0.0003526771868838385, -0.004160146470659937)
# Current Fuel Mass = 0.0
#
#
# Timestep = 295
# Lander Position = (1.1292141756694622e-08, -0.00035267739063623476, -0.004160165077999792)
# Current Fuel Mass = 0.0
#
#
# Timestep = 296
# Lander Position = (2.2826731260837136e-08, -0.0003526771870339641, -0.004160146484380545)
# Current Fuel Mass = 0.0
#
#
# Timestep = 297
# Lander Position = (2.2661466616441413e-08, -0.00035267712121893357, -0.004160140473965868)
# Current Fuel Mass = 0.0
#
#
# Timestep = 298
# Lander Position = (1.0798329273062193e-08, -0.0003526771927293139, -0.004160147004586947)
# Current Fuel Mass = 0.0
#
#
# Timestep = 299
# Lander Position = (-1.2760786544522863e-08, -0.00035267740110749257, -0.004160166034358566)
# Current Fuel Mass = 0.0
#
#
# Timestep = 300
# Lander Position = (-2.4657883055912745e-08, -0.0003526771912538513, -0.004160146869844471)
# Current Fuel Mass = 0.0
#
#
# Timestep = 301
# Lander Position = (-2.4855070511935066e-08, -0.000352677119360689, -0.004160140304354482)
# Current Fuel Mass = 0.0
#
#
# Timestep = 302
# Lander Position = (-1.335433226388686e-08, -0.00035267718495298037, -0.004160146294521346)
# Current Fuel Mass = 0.0
#
#
# Timestep = 303
# Lander Position = (9.84243616829202e-09, -0.0003526773875603331, -0.004160164797301314)
# Current Fuel Mass = 0.0
#
#
# Timestep = 304
# Lander Position = (2.1377953317016738e-08, -0.0003526771855009073, -0.004160146344581451)
# Current Fuel Mass = 0.0
#
#
# Timestep = 305
# Lander Position = (2.1213610520568475e-08, -0.0003526771211046156, -0.004160140463729846)
# Current Fuel Mass = 0.0
#
#
# Timestep = 306
# Lander Position = (9.351389601301748e-09, -0.0003526771939194055, -0.004160147113469538)
# Current Fuel Mass = 0.0
#
#
# Timestep = 307
# Lander Position = (-1.4206814755759982e-08, -0.0003526774034968181, -0.004160166252750042)
# Current Fuel Mass = 0.0
#
#
# Timestep = 308
# Lander Position = (-2.6102849141828405e-08, -0.0003526771921597549, -0.004160146952762914)
# Current Fuel Mass = 0.0
#
#
# Timestep = 309
# Lander Position = (-2.6298980063989375e-08, -0.0003526771189026457, -0.00416014026271343)
# Current Fuel Mass = 0.0
#
#
# Timestep = 310
# Lander Position = (-1.4797190517875378e-08, -0.0003526771832410581, -0.004160146138376225)
# Current Fuel Mass = 0.0
#
#
# Timestep = 311
# Lander Position = (8.400624420520728e-09, -0.0003526773846957869, -0.004160164535903909)
# Current Fuel Mass = 0.0
#
#
# Timestep = 312
# Lander Position = (1.9937337701790242e-08, -0.0003526771841521325, -0.004160146221611077)
# Current Fuel Mass = 0.0
#
#
# Timestep = 313
# Lander Position = (1.9774185287236014e-08, -0.0003526771211494297, -0.004160140468025792)
# Current Fuel Mass = 0.0
#
#
# Timestep = 314
# Lander Position = (7.913149366936657e-09, -0.00035267719524524854, -0.00416014723474892)
# Current Fuel Mass = 0.0
#
#
# Timestep = 315
# Lander Position = (-1.5643874919523142e-08, -0.0003526774060001429, -0.0041601664815518295)
# Current Fuel Mass = 0.0
#
#
# Timestep = 316
# Lander Position = (-2.753857990487086e-08, -0.0003526771931816571, -0.004160147046274346)
# Current Fuel Mass = 0.0
#
#
# Timestep = 317
# Lander Position = (-2.7733387071516535e-08, -0.00035267711856268015, -0.004160140231855292)
# Current Fuel Mass = 0.0
#
#
# Timestep = 318
# Lander Position = (-1.6230279056619745e-08, -0.0003526771816493683, -0.004160145993210759)
# Current Fuel Mass = 0.0
#
#
# Timestep = 319
# Lander Position = (6.9688495094872895e-09, -0.00035267738195369667, -0.004160164285689081)
# Current Fuel Mass = 0.0
#
#
# Timestep = 320
# Lander Position = (1.8507024686636852e-08, -0.00035267718290394934, -0.004160146107826618)
# Current Fuel Mass = 0.0
#
#
# Timestep = 321
# Lander Position = (1.8345328442532375e-08, -0.00035267712127448077, -0.0041601404796488325)
# Current Fuel Mass = 0.0
#
#
# Timestep = 322
# Lander Position = (6.485743331511262e-09, -0.0003526771966323629, -0.0041601473616234026)
# Current Fuel Mass = 0.0
#
#
# Timestep = 323
# Lander Position = (-1.7069835056304454e-08, -0.0003526774085470515, -0.004160166714333455)
# Current Fuel Mass = 0.0
#
#
# Timestep = 324
# Lander Position = (-2.8962946345370414e-08, -0.0003526771942566637, -0.004160147144635124)
# Current Fuel Mass = 0.0
# Timestep = 325
# Lander Position = (-2.9156165484978395e-08, -0.00035267711828481805, -0.004160140206668334)
# Current Fuel Mass = 0.0
#
#
# Timestep = 326
# Lander Position = (-1.7651474753153403e-08, -0.0003526771801282985, -0.004160145854494172)
# Current Fuel Mass = 0.0
#
#
# Timestep = 327
# Lander Position = (5.549231665050373e-09, -0.0003526773792902986, -0.004160164042660215)
# Current Fuel Mass = 0.0
#
#
# Timestep = 328
# Lander Position = (1.708913137022708e-08, -0.0003526771817142211, -0.00416014599938002)
# Current Fuel Mass = 0.0
#
#
# Timestep = 329
# Lander Position = (1.6929153947189016e-08, -0.00035267712143912907, -0.0041601404948876)
# Current Fuel Mass = 0.0
#
#
# Timestep = 330
# Lander Position = (5.071282312035511e-09, -0.00035267719804148965, -0.004160147490507744)
# Current Fuel Mass = 0.0
#
#
# Timestep = 331
# Lander Position = (-1.8482587498368363e-08, -0.00035267741109955807, -0.004160166947625994)
# Current Fuel Mass = 0.0
#
#
# Timestep = 332
# Lander Position = (-3.037384415048474e-08, -0.0003526771953516906, -0.004160147244823964)
# Current Fuel Mass = 0.0
#
#
# Timestep = 333
# Lander Position = (-3.056521432697786e-08, -0.00035267711804048204, -0.004160140184542833)
# Current Fuel Mass = 0.0
#
#
# Timestep = 334
# Lander Position = (-1.905867994747892e-08, -0.00035267717865341387, -0.004160145719995084)
# Current Fuel Mass = 0.0
#
#
# Timestep = 335
# Lander Position = (4.14386524618432e-09, -0.0003526773766849683, -0.0041601638049339066)
# Current Fuel Mass = 0.0
#
#
# Timestep = 336
# Lander Position = (1.5685748587227933e-08, -0.00035267718056212257, -0.0041601458943695095)
# Current Fuel Mass = 0.0
#
#
# Timestep = 337
# Lander Position = (1.5527749112457975e-08, -0.0003526771216223696, -0.004160140511823923)
# Current Fuel Mass = 0.0
#
#
# Timestep = 338
# Lander Position = (3.671850097083007e-09, -0.00035267719945146074, -0.0041601476194688914)
# Current Fuel Mass = 0.0
#
#
# Timestep = 339
# Lander Position = (-1.9880051978900952e-08, -0.00035267741363634775, -0.004160167179482998)
# Current Fuel Mass = 0.0
#
#
# Timestep = 340
# Lander Position = (-3.176919678333453e-08, -0.00035267719644896205, -0.004160147345217616)
# Current Fuel Mass = 0.0
#
#
# Timestep = 341
# Lander Position = (-3.195846077672212e-08, -0.00035267711781514845, -0.004160140164152528)
# Current Fuel Mass = 0.0
#
#
# Timestep = 342
# Lander Position = (-2.0449825521783414e-08, -0.00035267717721318176, -0.004160145588660366)
# Current Fuel Mass = 0.0
#
#
# Timestep = 343
# Lander Position = (2.7548156798810117e-09, -0.00035267737412891895, -0.004160163571707764)
# Current Fuel Mass = 0.0
#
#
# Timestep = 344
# Lander Position = (1.4298937858394145e-08, -0.00035267717943775233, -0.0041601457918909075)
# Current Fuel Mass = 0.0
#
#
# Timestep = 345
# Lander Position = (1.414317155737501e-08, -0.0003526771218132786, -0.004160140529460248)
# Current Fuel Mass = 0.0
#
#
# Timestep = 346
# Lander Position = (2.2895004084094065e-09, -0.0003526772008504154, -0.004160147747423699)
# Current Fuel Mass = 0.0
#
#
# Timestep = 347
# Lander Position = (-2.1260178669536694e-08, -0.00035267741614470135, -0.00416016740874294)
# Current Fuel Mass = 0.0
#
#
# Timestep = 348
# Lander Position = (-3.314695851666352e-08, -0.0003526771975385792, -0.004160147444912107)
# Current Fuel Mass = 0.0
#
#
# Timestep = 349
# Lander Position = (-3.333386319630987e-08, -0.0003526771176015099, -0.004160140144830106)
# Current Fuel Mass = 0.0
#
#
# Timestep = 350
# Lander Position = (-2.1822873916761823e-08, -0.00035267717580267274, -0.004160145460039852)
# Current Fuel Mass = 0.0
#
#
# Timestep = 351
# Lander Position = (1.3841164564032474e-09, -0.0003526773716194076, -0.004160163342731295)
# Current Fuel Mass = 0.0
#
#
# Timestep = 352
# Lander Position = (1.2930728395278454e-08, -0.0003526771783368006, -0.004160145691550641)
# Current Fuel Mass = 0.0
#
#
# Timestep = 353
# Lander Position = (1.2777446221219038e-08, -0.0003526771220061085, -0.004160140547271673)
# Current Fuel Mass = 0.0
#
#
# Timestep = 354
# Lander Position = (9.262539190086628e-10, -0.00035267720223128746, -0.00416014787372689)
# Current Fuel Mass = 0.0
#
#
# Timestep = 355
# Lander Position = (-2.2620951158064324e-08, -0.00035267741861634284, -0.004160167634650088)
# Current Fuel Mass = 0.0
#
#
# Timestep = 356
# Lander Position = (-3.4505117403874366e-08, -0.00035267719861469633, -0.004160147543373639)
# Current Fuel Mass = 0.0
#
#
# Timestep = 357
# Lander Position = (-3.468941409504041e-08, -0.00035267711739595214, -0.004160140126245565)
# Current Fuel Mass = 0.0
#
#
# Timestep = 358
# Lander Position = (-2.3175822088766245e-08, -0.0003526771744203235, -0.004160145333990849)
# Current Fuel Mass = 0.0
#
#
# Timestep = 359
# Lander Position = (3.3766181106066955e-11, -0.00035267736915675147, -0.004160163118033554)
# Current Fuel Mass = 0.0
#
#
# Timestep = 360
# Lander Position = (2.3252333008520035e-08, -0.0003526773067477172, -0.004160157418539513)
# Current Fuel Mass = 0.0
#
#
# Timestep = 361
# Lander Position = (3.478860130889614e-08, -0.00035267709903313507, -0.004160138449387463)
# Current Fuel Mass = 0.0
#
#
# Timestep = 362
# Lander Position = (3.462503962129031e-08, -0.0003526770294487452, -0.004160132094718975)
# Current Fuel Mass = 0.0
#
#
# Timestep = 363
# Lander Position = (2.2763616476605714e-08, -0.00035267709748976303, -0.004160138308554218)
# Current Fuel Mass = 0.0
#
#
# Timestep = 364
# Lander Position = (-7.937750875244817e-10, -0.00035267730267465284, -0.004160157046812839)
# Current Fuel Mass = 0.0
#
#
# Timestep = 365
# Lander Position = (-1.2690378964155835e-08, -0.0003526771114930654, -0.004160139587475575)
# Current Fuel Mass = 0.0
#
#
# Timestep = 366
# ...
#
#
# Timestep = 878
# Lander Position = (1.056812186081056e-08, -0.0003526772025883291, -0.004160147918997779)
# Current Fuel Mass = 0.0
#
#
# Timestep = 879
# Lander Position = (1.0389068967349213e-08, -0.0003526771467442553, -0.0041601428191200725)
# Current Fuel Mass = 0.0
#
#
# Timestep = 880
# Lander Position = (-1.487902117315984e-09, -0.0003526772274241434, -0.004160150187104023)
# Current Fuel Mass = 0.0
#
#
# Timestep = 881
# Lander Position = (-1.7189394638921095e-09, -0.00035267717315663895, -0.00416014523120357)
# Current Fuel Mass = 0.0
#
#
# Timestep = 882
# Lander Position = (9.748031414708235e-09, -0.0003526772549183443, -0.004160152697952249)
# Current Fuel Mass = 0.0
#
#
# Timestep = 883
# Lander Position = (9.56878169477318e-09, -0.0003526771956295666, -0.004160147283499972)
# Current Fuel Mass = 0.0
#
#
# Timestep = 884
# Lander Position = (-2.3083721806158936e-09, -0.00035267727314055973, -0.004160154362080439)
# Current Fuel Mass = 0.0
#
#
# Timestep = 885
# Lander Position = (-2.539526031455054e-09, -0.00035267721447441086, -0.004160149004488119)
# Current Fuel Mass = 0.0
#
#
# Timestep = 886
# Lander Position = (8.927311190506e-09, -0.0003526772921891358, -0.004160156101650062)
# Current Fuel Mass = 0.0
#
#
# Timestep = 887
# Lander Position = (8.748022617322767e-09, -0.00035267723065919826, -0.004160150482533091)
# Current Fuel Mass = 0.0
#
#
# Timestep = 888
# Lander Position = (-3.129160892060346e-09, -0.0003526773061084241, -0.004160157372818951)
# Current Fuel Mass = 0.0
#
#
# Timestep = 889
# Lander Position = (-3.3602738432975817e-09, -0.000352677244065025, -0.0041601517068105345)
# Current Fuel Mass = 0.0
#
#
# Timestep = 890
# Lander Position = (8.106591151756332e-09, -0.0003526773186726025, -0.004160158520216438)
# Current Fuel Mass = 0.0
#
#
# Timestep = 891
# Lander Position = (7.92742121330422e-09, -0.00035267725576272824, -0.00416015277508303)
# Current Fuel Mass = 0.0
#
#
# Timestep = 892
# Lander Position = (-3.949637898288573e-09, -0.00035267732994237846, -0.004160159549421272)
# Current Fuel Mass = 0.0
#
#
# Timestep = 893
# Lander Position = (-4.1805529862701776e-09, -0.0003526772652545124, -0.004160153641915797)
# Current Fuel Mass = 0.0
#
#
# Timestep = 894
# Lander Position = (7.286499624314442e-09, -0.0003526773374292515, -0.0041601602331470915)
# Current Fuel Mass = 0.0
#
#
# Timestep = 895
# Lander Position = (7.107605220012254e-09, -0.0003526772737552584, -0.004160154418234562)
# Current Fuel Mass = 0.0
#
#
# Timestep = 896
# Lander Position = (-4.769175075237359e-09, -0.0003526773472317494, -0.004160161128353126)
# Current Fuel Mass = 0.0
#
#
# Timestep = 897
# Lander Position = (-4.999735909144795e-09, -0.00035267728042560816, -0.00416015502740324)
# Current Fuel Mass = 0.0
#
#
# Timestep = 898
# Lander Position = (6.467662765423776e-09, -0.0003526773506517517, -0.004160161440683406)
# Current Fuel Mass = 0.0
#
#
# Timestep = 899
# Lander Position = (6.289200099331717e-09, -0.00035267728665348467, -0.00416015559615893)
# Current Fuel Mass = 0.0
#
#
# Timestep = 900
# Lander Position = (-5.5871469572665695e-09, -0.0003526773598313356, -0.0041601622790004645)
# Current Fuel Mass = 0.0
#
#
# Timestep = 901
# Lander Position = (-5.817197847182419e-09, -0.0003526772912852819, -0.004160156019158755)
# Current Fuel Mass = 0.0
#
#
# Timestep = 902
# Lander Position = (5.6507040513881724e-09, -0.00035267735991106696, -0.004160162286290498)
# Current Fuel Mass = 0.0
#
#
# Timestep = 903
# Lander Position = (5.472828522695781e-09, -0.0003526772959021369, -0.004160156440793362)
# Current Fuel Mass = 0.0
#
#
# Timestep = 904
# Lander Position = (-6.402931176140892e-09, -0.0003526773690697329, -0.004160163122694572)
# Current Fuel Mass = 0.0
#
#
# Timestep = 905
# Lander Position = (-6.632317256881049e-09, -0.00035267729905639165, -0.00416015672885749)
# Current Fuel Mass = 0.0
# Timestep = 906
# Lander Position = (4.836243780477666e-09, -0.0003526773663327748, -0.0041601628727593615)
# Current Fuel Mass = 0.0
#
#
# Timestep = 907
# Lander Position = (4.659109872714297e-09, -0.0003526773025361959, -0.004160157046655459)
# Current Fuel Mass = 0.0
#
#
# Timestep = 908
# Lander Position = (-7.215908904850015e-09, -0.0003526773758985722, -0.0041601637463411275)
# Current Fuel Mass = 0.0
#
#
# Timestep = 909
# Lander Position = (-7.4444762575296605e-09, -0.0003526773046149837, -0.004160157236502643)
# Current Fuel Mass = 0.0
#
#
# Timestep = 910
# Lander Position = (4.0248985868474035e-09, -0.00035267737072338284, -0.0041601632737425535)
# Current Fuel Mass = 0.0
#
#
# Timestep = 911
# Lander Position = (3.848659756357848e-09, -0.0003526773072971022, -0.004160157481455768)
# Current Fuel Mass = 0.0
#
#
# Timestep = 912
# Lander Position = (-8.02546530499113e-09, -0.00035267738099943315, -0.004160164212183899)
# Current Fuel Mass = 0.0
#
#
# Timestep = 913
# Lander Position = (-8.253061075741014e-09, -0.0003526773085886521, -0.004160157599407926)
# Current Fuel Mass = 0.0
#
#
# Timestep = 914
# Lander Position = (3.2172809642599727e-09, -0.0003526773736608176, -0.004160163542017902)
# Current Fuel Mass = 0.0
#
#
# Timestep = 915
# Lander Position = (3.0420895288332663e-09, -0.0003526773107160085, -0.004160157793700689)
# Current Fuel Mass = 0.0
#
#
# Timestep = 916
# Lander Position = (-8.83098997412391e-09, -0.0003526773848604364, -0.004160164564799417)
# Current Fuel Mass = 0.0
#
#
# Timestep = 917
# Lander Position = (-9.057462490534557e-09, -0.00035267731142700476, -0.0041601578586328266)
# Current Fuel Mass = 0.0
#
#
# Timestep = 918
# Lander Position = (2.413998799271028e-09, -0.00035267737555925283, -0.004160163715408894)
# Current Fuel Mass = 0.0
#
#
# Timestep = 919
# Lander Position = (2.2400058266396994e-09, -0.0003526773131734191, -0.004160158018138974)
# Current Fuel Mass = 0.0
#
#
# Timestep = 920
# Lander Position = (-9.631877391907433e-09, -0.00035267738783111127, -0.004160164836107646)
# Current Fuel Mass = 0.0
#
#
# Timestep = 921
# Lander Position = (-9.857076277967905e-09, -0.0003526773134521388, -0.0041601580435922094)
# Current Fuel Mass = 0.0
#
#
# Timestep = 922
# Lander Position = (1.6156549103764681e-09, -0.000352677376715547, -0.004160163821025471)
# Current Fuel Mass = 0.0
#
#
# Timestep = 923
# Lander Position = (1.44301010785306e-09, -0.00035267731494191497, -0.004160158179663516)
# Current Fuel Mass = 0.0
#
#
# Timestep = 924
# Lander Position = (-1.0427527364120377e-08, -0.0003526773901617053, -0.0041601650489618966)
# Current Fuel Mass = 0.0
#
#
# Timestep = 925
# Lander Position = (-1.0651303652687992e-08, -0.0003526773148948075, -0.00416015817535911)
# Current Fuel Mass = 0.0
#
#
# Timestep = 926
# Lander Position = (8.228465968549824e-10, -0.0003526773773425169, -0.004160163878302628)
# Current Fuel Mass = 0.0
#
#
# Timestep = 927
# Lander Position = (6.516982016885107e-10, -0.00035267731621676525, -0.004160158296106839)
# Current Fuel Mass = 0.0
#
#
# Timestep = 928
# Lander Position = (-1.1217345461745886e-08, -0.0003526773920313445, -0.00416016521972041)
# Current Fuel Mass = 0.0
#
#
# Timestep = 929
# Lander Position = (-1.1439551705423088e-08, -0.000352677315920325, -0.0041601582690305025)
# Current Fuel Mass = 0.0
#
#
# Timestep = 930
# Lander Position = (3.616519307200421e-11, -0.0003526773775927696, -0.004160163901176852)
# Current Fuel Mass = 0.0
#
#
# Timestep = 931
# Lander Position = (1.1522728038095983e-08, -0.0003526773147277472, -0.004160158160098243)
# Current Fuel Mass = 0.0
#
#
# Timestep = 932
# Lander Position = (1.1336147871723836e-08, -0.00035267724912760654, -0.004160152169350155)
# Current Fuel Mass = 0.0
#
#
# Timestep = 933
# Lander Position = (-5.483042993463623e-10, -0.0003526773208469834, -0.004160158719013188)
# Current Fuel Mass = 0.0
#
#
# Timestep = 934
# Lander Position = (-7.869392309524245e-10, -0.00035267725986692873, -0.004160153150114207)
# Current Fuel Mass = 0.0
#
#
# Timestep = 935
# Lander Position = (1.0672408652329106e-08, -0.0003526773354462795, -0.004160160052255384)
# Current Fuel Mass = 0.0
#
#
# Timestep = 936
# Lander Position = (1.0485481572407982e-08, -0.00035267726896785225, -0.0041601539812342915)
# Current Fuel Mass = 0.0
#
#
# Timestep = 937
# Lander Position = (-1.3993198017674294e-09, -0.00035267733987113067, -0.004160160456370582)
# Current Fuel Mass = 0.0
#
#
# Timestep = 938
# Lander Position = (-1.6382251465105913e-09, -0.0003526772765985675, -0.004160154678115752)
# Current Fuel Mass = 0.0
#
#
# Timestep = 939
# Lander Position = (9.820843585613444e-09, -0.000352677350068459, -0.004160161387615021)
# Current Fuel Mass = 0.0
#
#
# Timestep = 940
# Lander Position = (9.633727575599753e-09, -0.00035267728319031253, -0.0041601552800923725)
# Current Fuel Mass = 0.0
#
#
# Timestep = 941
# Lander Position = (-2.2512607844513903e-09, -0.0003526773537261036, -0.00416016172166407)
# Current Fuel Mass = 0.0
#
#
# Timestep = 942
# Lander Position = (-2.4902726521846216e-09, -0.00035267728857559183, -0.00416015577191163)
# Current Fuel Mass = 0.0
#
#
# Timestep = 943
# Lander Position = (8.9686824319135e-09, -0.0003526773603175711, -0.004160162323613756)
# Current Fuel Mass = 0.0
#
#
# Timestep = 944
# Lander Position = (8.781541327011838e-09, -0.00035267729338824385, -0.004160156211418448)
# Current Fuel Mass = 0.0
#
#
# Timestep = 945
# Lander Position = (-3.103471603380412e-09, -0.0003526773638770586, -0.004160162648696129)
# Current Fuel Mass = 0.0
#
#
# Timestep = 946
# Lander Position = (-3.3424264787234503e-09, -0.0003526772971465312, -0.004160156554653722)
# Current Fuel Mass = 0.0
#
#
# Timestep = 947
# Lander Position = (8.116579622141892e-09, -0.0003526773674348463, -0.004160162973604383)
# Current Fuel Mass = 0.0
#
#
# Timestep = 948
# Lander Position = (7.929576785065285e-09, -0.000352677300702992, -0.004160156879443728)
# Current Fuel Mass = 0.0
#
#
# Timestep = 949
# Lander Position = (-3.955298375993356e-09, -0.0003526773713734467, -0.004160163333305667)
# Current Fuel Mass = 0.0
#
#
# Timestep = 950
# Lander Position = (-4.194033247766008e-09, -0.0003526773032774627, -0.004160157114567102)
# Current Fuel Mass = 0.0
#
#
# Timestep = 951
# Lander Position = (7.265187698877874e-09, -0.00035267737230965736, -0.004160163418806935)
# Current Fuel Mass = 0.0
#
#
# Timestep = 952
# Lander Position = (7.078485900518674e-09, -0.0003526773059521956, -0.004160157358837388)
# Current Fuel Mass = 0.0
#
#
# Timestep = 953
# Lander Position = (-4.8060894582000115e-09, -0.0003526773769669113, -0.004160163844134897)
# Current Fuel Mass = 0.0
#
#
# Timestep = 954
# Lander Position = (-5.044441947027632e-09, -0.0003526773076604777, -0.004160157514855605)
# Current Fuel Mass = 0.0
#
#
# Timestep = 955
# Lander Position = (6.415156805940654e-09, -0.0003526773755793059, -0.004160163717421562)
# Current Fuel Mass = 0.0
#
#
# Timestep = 956
# Lander Position = (6.228918105895985e-09, -0.0003526773097215937, -0.004160157703090832)
# Current Fuel Mass = 0.0
#
#
# Timestep = 957
# Lander Position = (-5.655195923992394e-09, -0.0003526773811957527, -0.004160164230342895)
# Current Fuel Mass = 0.0
#
#
# Timestep = 958
# Lander Position = (-5.8930044077081e-09, -0.0003526773107913889, -0.004160157800798279)
# Current Fuel Mass = 0.0
#
#
# Timestep = 959
# Lander Position = (5.56713418596277e-09, -0.0003526773777005148, -0.004160163911157443)
# Current Fuel Mass = 0.0
#
#
# Timestep = 960
# Lander Position = (5.381519812736391e-09, -0.0003526773124307952, -0.0041601579505239706)
# Current Fuel Mass = 0.0
#
#
# Timestep = 961
# Lander Position = (-6.501972045467429e-09, -0.00035267738444543694, -0.004160164527131459)
# Current Fuel Mass = 0.0
#
#
# Timestep = 962
# Lander Position = (-6.739075782607213e-09, -0.00035267731302539594, -0.00416015800483296)
# Current Fuel Mass = 0.0
#
#
# Timestep = 963
# Lander Position = (4.7217636851613674e-09, -0.0003526773790006382, -0.0041601640299094265)
# Current Fuel Mass = 0.0
#
#
# Timestep = 964
# Lander Position = (4.536933916842066e-09, -0.0003526773143803951, -0.004160158128587969)
# Current Fuel Mass = 0.0
#
#
# Timestep = 965
# Lander Position = (-7.345775771023742e-09, -0.0003526773869919409, -0.004160164759703592)
# Current Fuel Mass = 0.0
#
#
# Timestep = 966
# Lander Position = (-7.582015022898948e-09, -0.0003526773146169645, -0.00416015815019823)
# Current Fuel Mass = 0.0
#
#
# Timestep = 967
# Lander Position = (3.879685263897811e-09, -0.0003526773797143508, -0.004160164095108693)
# Current Fuel Mass = 0.0
#
#
# Timestep = 968
# Lander Position = (3.6957993093255347e-09, -0.00035267731578573027, -0.004160158256948067)
# Current Fuel Mass = 0.0
#
#
# Timestep = 969
# Lander Position = (-8.185969201874217e-09, -0.0003526773890328102, -0.0041601649460996926)
# Current Fuel Mass = 0.0
#
#
# Timestep = 970
# Lander Position = (-8.421185353213155e-09, -0.00035267731574839994, -0.004160158253542702)
# Current Fuel Mass = 0.0
# Timestep = 971
# Lander Position = (3.0415345135385202e-09, -0.000352677380009935, -0.0041601641221232)
# Current Fuel Mass = 0.0
#
#
# Timestep = 972
# Lander Position = (2.8587503942328186e-09, -0.00035267731680105834, -0.004160158349691467)
# Current Fuel Mass = 0.0
#
#
# Timestep = 973
# Lander Position = (-9.021919065550628e-09, -0.0003526773907094024, -0.004160165099228897)
# Current Fuel Mass = 0.0
#
#
# Timestep = 974
# Lander Position = (-9.255954743510427e-09, -0.0003526773165503071, -0.0041601583267936075)
# Current Fuel Mass = 0.0
#
#
# Timestep = 975
# Lander Position = (2.2079421793043154e-09, -0.0003526773800081025, -0.0041601641219766875)
# Current Fuel Mass = 0.0
#
#
# Timestep = 976
# Lander Position = (2.0264166125300884e-09, -0.00035267731753688115, -0.004160158416909525)
# Current Fuel Mass = 0.0
#
#
# Timestep = 977
# Lander Position = (-9.852997184766241e-09, -0.00035267739212282545, -0.004160165228324678)
# Current Fuel Mass = 0.0
#
#
# Timestep = 978
# Lander Position = (-1.0085696376380767e-08, -0.00035267731711625613, -0.00416015837849604)
# Current Fuel Mass = 0.0
#
#
# Timestep = 979
# Lander Position = (1.3795336885579233e-09, -0.00035267737979548827, -0.004160164102580919)
# Current Fuel Mass = 0.0
#
#
# Timestep = 980
# Lander Position = (1.1994219713388442e-09, -0.0003526773180723542, -0.0041601584658309656)
# Current Fuel Mass = 0.0
#
#
# Timestep = 981
# Lander Position = (-1.0678580942735672e-08, -0.00035267739334535675, -0.004160165339987603)
# Current Fuel Mass = 0.0
#
#
# Timestep = 982
# Lander Position = (-1.0909789110852585e-08, -0.00035267731751328766, -0.004160158414772344)
# Current Fuel Mass = 0.0
#
#
# Timestep = 983
# Lander Position = (5.569286857777809e-10, -0.0003526773794343119, -0.0041601640696179)
# Current Fuel Mass = 0.0
#
#
# Timestep = 984
# Lander Position = (1.2034490697015615e-08, -0.0003526773164210877, -0.004160158315003921)
# Current Fuel Mass = 0.0
#
#
# Timestep = 985
# Lander Position = (1.1838892338940745e-08, -0.000352677250325449, -0.00416015227900592)
# Current Fuel Mass = 0.0
#
#
# Timestep = 986
# Lander Position = (-5.4574311058110536e-11, -0.00035267732159706075, -0.00416015878777908)
# Current Fuel Mass = 0.0
#
#
# Timestep = 987
# Lander Position = (-3.0226168653617455e-10, -0.0003526772608998881, -0.0041601532447137195)
# Current Fuel Mass = 0.0
#
#
# Timestep = 988
# Lander Position = (1.1148036618652034e-08, -0.0003526773367313851, -0.004160160169880066)
# Current Fuel Mass = 0.0
#
#
# Timestep = 989
# Lander Position = (1.0952024705490256e-08, -0.0003526772698234826, -0.004160154059638389)
# Current Fuel Mass = 0.0
#
#
# Timestep = 990
# Lander Position = (-9.418580420198177e-10, -0.0003526773403397786, -0.004160160499435625)
# Current Fuel Mass = 0.0
#
#
# Timestep = 991
# Lander Position = (-1.189878918370639e-09, -0.0003526772773391904, -0.004160154746018335)
# Current Fuel Mass = 0.0
#
#
# Timestep = 992
# Lander Position = (1.0260077131355115e-08, -0.0003526773510511337, -0.0041601614776210615)
# Current Fuel Mass = 0.0
#
#
# Timestep = 993
# Lander Position = (1.0063816780915303e-08, -0.0003526772838012008, -0.004160155336146092)
# Current Fuel Mass = 0.0
#
#
# Timestep = 994
# Lander Position = (-1.8303126627133542e-09, -0.0003526773540031416, -0.004160161747230852)
# Current Fuel Mass = 0.0
#
#
# Timestep = 995
# Lander Position = (-2.078495981426913e-09, -0.00035267728910637336, -0.004160155820650969)
# Current Fuel Mass = 0.0
#
#
# Timestep = 996
# Lander Position = (9.371290453830975e-09, -0.00035267736107357666, -0.004160162392919922)
# Current Fuel Mass = 0.0
#
#
# Timestep = 997
# Lander Position = (9.174952679102217e-09, -0.0003526772938242192, -0.0041601562514987775)
# Current Fuel Mass = 0.0
#
#
# Timestep = 998
# Lander Position = (-2.7192538453410442e-09, -0.00035267736402685014, -0.004160162662642472)
# Current Fuel Mass = 0.0
#
#
# Timestep = 999
# Lander Position = (-2.967428900991049e-09, -0.00035267729752657057, -0.0041601565896269115)
# Current Fuel Mass = 0.0
