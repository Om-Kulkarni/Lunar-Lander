# %%
import pybullet as p
import pybullet_data
from pybullet_object_models import ycb_objects
import numpy as np
import time
import math as m
import os, inspect

# %%
# Scaling factors for force and torque
ALPHA = 300
BETA = 3

DURATION = 1000

# %%
p.disconnect()

# %%
# ------------------------ #
# --- Setup simulation --- #
# ------------------------ #

# Create pybullet GUI
physics_client_id = p.connect(p.GUI)
p.resetDebugVisualizerCamera(1.8, 120, -50, [0.0, -0.0, -0.0])
p.resetSimulation()
p.setPhysicsEngineParameter(numSolverIterations=150)
sim_timestep = 1.0/240
p.setTimeStep(sim_timestep)
p.setRealTimeSimulation(0)

p.loadURDF(os.path.join(pybullet_data.getDataPath(), "plane.urdf"))
# Out:
# 0

# %%
p.setGravity(0, 0, -9.8)

# %%
sphereId = p.loadURDF(os.path.join(pybullet_data.getDataPath(), "sphere2red.urdf"), [3, 4, 2])

# %%
urdf_path = r"Lunar_Lander.urdf"
landerId = p.loadURDF(urdf_path, useFixedBase=True, basePosition=[0, 0, 0.5])

# %%
# 6 DOF Forces and Torques
# F_x = p.addUserDebugParameter('F_x', -2, 2, 0)
# F_y = p.addUserDebugParameter('F_y', -2, 2, 0)
# F_z = p.addUserDebugParameter('F_z', -2, 2, 0)

# T_x = p.addUserDebugParameter('T_x', -2, 2, 0)
# T_y = p.addUserDebugParameter('T_y', -2, 2, 0)
# T_z = p.addUserDebugParameter('T_z', -2, 2, 0)

# %%
for i in range(DURATION):

    p.stepSimulation()
    time.sleep(1./240.)

#     user_F_x = p.readUserDebugParameter(F_x)
#     user_F_y = p.readUserDebugParameter(F_y)
#     user_F_z = p.readUserDebugParameter(F_z)

#     user_T_x = p.readUserDebugParameter(T_x)
#     user_T_y = p.readUserDebugParameter(T_y)
#     user_T_z = p.readUserDebugParameter(T_z)

    landerPos, landerOrn = p.getBasePositionAndOrientation(landerId)
    spherePos, sphereOrn = p.getBasePositionAndOrientation(sphereId)

    force = ALPHA * (np.array(spherePos) - np.array(landerPos))
    #force = (np.array([F_x, F_y, F_z]))
    #torque = (np.array([T_x, T_y, T_z]))

    p.applyExternalForce(objectUniqueId=landerId, linkIndex=-1,
                         forceObj=force, posObj=landerPos, flags=p.WORLD_FRAME)

#     p.applyExternalTorque(objectUniqueId=robotID, linkIndex=-1,
#                         torqueObj=torque, flags=p.WORLD_FRAME)

    print('Applied force vector = {}'.format(force))
    print('Applied force magnitude = {}'.format(np.linalg.norm(force)))

#     print('Applied torque vector = {}'.format(torque))
#     print('Applied torque magnitude = {}'.format(np.linalg.norm(torque)))
# Out:
# Applied force vector = [ 900.         1200.          449.94895833]
# Applied force magnitude = 1566.03131038471
# Applied force vector = [ 900.         1200.          449.84688385]
# Applied force magnitude = 1566.001985603286
# Applied force vector = [ 900.         1200.          449.69378611]
# Applied force magnitude = 1565.958013889958
# Applied force vector = [ 900.         1200.          449.48967534]
# Applied force magnitude = 1565.899411915778
# Applied force vector = [ 900.         1200.          449.23456248]
# Applied force magnitude = 1565.8262011236009
# Applied force vector = [ 900.         1200.          448.92845915]
# Applied force magnitude = 1565.7384077267998
# Applied force vector = [ 900.         1200.          448.57137766]
# Applied force magnitude = 1565.6360627082986
# Applied force vector = [ 900.         1200.          448.16333102]
# Applied force magnitude = 1565.5192018199198
# Applied force vector = [ 900.         1200.          447.70433292]
# Applied force magnitude = 1565.3878655820415
# Applied force vector = [ 900.         1200.          447.19439774]
# Applied force magnitude = 1565.2420992835657
# Applied force vector = [ 900.         1200.          446.63354056]
# Applied force magnitude = 1565.0819529821888
# Applied force vector = [ 900.         1200.          446.02177713]
# Applied force magnitude = 1564.9074815049769
# Applied force vector = [ 900.         1200.          445.35912389]
# Applied force magnitude = 1564.7187444492363
# Applied force vector = [ 900.         1200.          444.64559798]
# Applied force magnitude = 1564.5158061836762
# Applied force vector = [ 900.        1200.         443.8812172]
# Applied force magnitude = 1564.2987358498626
# Applied force vector = [ 900.         1200.          443.06600006]
# Applied force magnitude = 1564.0676073639513
# Applied force vector = [ 900.         1200.          442.19996573]
# Applied force magnitude = 1563.8224994186987
# Applied force vector = [ 900.         1200.          441.28313407]
# Applied force magnitude = 1563.5634954857446
# Applied force vector = [ 900.         1200.          440.31552563]
# Applied force magnitude = 1563.290683818158
# Applied force vector = [ 900.         1200.          439.29716163]
# Applied force magnitude = 1563.004157453239
# Applied force vector = [ 900.         1200.          438.22806396]
# Applied force magnitude = 1562.7040142155747
# Applied force vector = [ 900.         1200.          437.10825521]
# Applied force magnitude = 1562.3903567203306
# Applied force vector = [ 900.         1200.          435.93775862]
# Applied force magnitude = 1562.0632923767812
# Applied force vector = [ 900.         1200.          434.71659812]
# Applied force magnitude = 1561.7229333920639
# Applied force vector = [ 900.         1200.          433.44479831]
# Applied force magnitude = 1561.3693967751474
# Applied force vector = [ 900.         1200.          432.12238447]
# Applied force magnitude = 1561.0028043410084
# Applied force vector = [ 900.         1200.          430.74938253]
# Applied force magnitude = 1560.6232827150036
# Applied force vector = [ 900.         1200.          429.32581911]
# Applied force magnitude = 1560.2309633374268
# Applied force vector = [ 900.         1200.          427.85172149]
# Applied force magnitude = 1559.8259824682432
# Applied force vector = [ 900.         1200.          426.32711761]
# Applied force magnitude = 1559.4084811919827
# Applied force vector = [ 900.         1200.          424.75203609]
# Applied force magnitude = 1558.9786054227893
# Applied force vector = [ 900.        1200.         423.1265062]
# Applied force magnitude = 1558.5365059096066
# Applied force vector = [ 900.         1200.          421.45055788]
# Applied force magnitude = 1558.082338241489
# Applied force vector = [ 900.         1200.          419.72422173]
# Applied force magnitude = 1557.6162628530265
# Applied force vector = [ 900.         1200.          417.94752899]
# Applied force magnitude = 1557.138445029867
# Applied force vector = [ 900.         1200.          416.12051159]
# Applied force magnitude = 1556.6490549143239
# Applied force vector = [ 900.         1200.          414.24320209]
# Applied force magnitude = 1556.14826751105
# Applied force vector = [ 900.         1200.          412.31563371]
# Applied force magnitude = 1555.6362626927678
# Applied force vector = [ 900.         1200.          410.33784033]
# Applied force magnitude = 1555.1132252060327
# Applied force vector = [ 900.         1200.          408.30985648]
# Applied force magnitude = 1554.5793446770208
# Applied force vector = [ 900.         1200.          406.23171731]
# Applied force magnitude = 1554.0348156173166
# Applied force vector = [ 900.         1200.          404.10345866]
# Applied force magnitude = 1553.4798374296868
# Applied force vector = [ 900.         1200.          401.92511698]
# Applied force magnitude = 1552.9146144138203
# Applied force vector = [ 900.         1200.          399.69672938]
# Applied force magnitude = 1552.3393557720156
# Applied force vector = [ 900.         1200.          397.41833361]
# Applied force magnitude = 1551.7542756147964
# Applied force vector = [ 900.         1200.          395.08996805]
# Applied force magnitude = 1551.1595929664336
# Applied force vector = [ 900.         1200.          392.71167172]
# Applied force magnitude = 1550.5555317703543
# Applied force vector = [ 900.         1200.          390.28348428]
# Applied force magnitude = 1549.9423208944152
# Applied force vector = [ 900.         1200.          387.80544601]
# Applied force magnitude = 1549.3201941360187
# Applied force vector = [ 900.         1200.          385.27759785]
# Applied force magnitude = 1548.6893902270485
# Applied force vector = [ 900.         1200.          382.69998132]
# Applied force magnitude = 1548.0501528386012
# Applied force vector = [ 900.         1200.          380.07263861]
# Applied force magnitude = 1547.40273058549
# Applied force vector = [ 900.         1200.          377.39561252]
# Applied force magnitude = 1546.747377030493
# Applied force vector = [ 900.         1200.          374.66894646]
# Applied force magnitude = 1546.0843506883275
# Applied force vector = [ 900.         1200.          371.89268448]
# Applied force magnitude = 1545.4139150293142
# Applied force vector = [ 900.         1200.          369.06687122]
# Applied force magnitude = 1544.7363384827129
# Applied force vector = [ 900.         1200.          366.19155195]
# Applied force magnitude = 1544.051894439696
# Applied force vector = [ 900.         1200.          363.26677257]
# Applied force magnitude = 1543.360861255936
# Applied force vector = [ 900.         1200.          360.29257957]
# Applied force magnitude = 1542.6635222537743
# Applied force vector = [ 900.         1200.          357.26902004]
# Applied force magnitude = 1541.9601657239439
# Applied force vector = [ 900.         1200.          354.19614169]
# Applied force magnitude = 1541.2510849268147
# Applied force vector = [ 900.         1200.          351.07399283]
# Applied force magnitude = 1540.5365780931286
# Applied force vector = [ 900.         1200.          347.90262237]
# Applied force magnitude = 1539.8169484241967
# Applied force vector = [ 900.         1200.          344.68207982]
# Applied force magnitude = 1539.0925040915197
# Applied force vector = [ 900.         1200.          341.41241528]
# Applied force magnitude = 1538.3635582358052
# Applied force vector = [ 900.         1200.          338.09367944]
# Applied force magnitude = 1537.6304289653413
# Applied force vector = [ 900.        1200.         334.7259236]
# Applied force magnitude = 1536.8934393536954
# Applied force vector = [ 900.         1200.          331.30919961]
# Applied force magnitude = 1536.1529174367045
# Applied force vector = [ 900.         1200.          327.84355995]
# Applied force magnitude = 1535.409196208713
# Applied force vector = [ 900.         1200.          324.32905765]
# Applied force magnitude = 1534.662613618032
# Applied force vector = [ 900.         1200.          320.76574633]
# Applied force magnitude = 1533.9135125615728
# Applied force vector = [ 900.         1200.          317.15368019]
# Applied force magnitude = 1533.162240878622
# Applied force vector = [ 900.         1200.          313.49291399]
# Applied force magnitude = 1532.4091513437183
# Applied force vector = [ 900.         1200.          309.78350308]
# Applied force magnitude = 1531.65460165859
# Applied force vector = [ 900.         1200.          306.02550337]
# Applied force magnitude = 1530.8989544431138
# Applied force vector = [ 900.         1200.          302.21897134]
# Applied force magnitude = 1530.1425772252542
# Applied force vector = [ 900.         1200.          298.36396402]
# Applied force magnitude = 1529.3858424299444
# Applied force vector = [ 900.         1200.          294.46053901]
# Applied force magnitude = 1528.6291273668603
# Applied force vector = [ 900.         1200.          290.50875447]
# Applied force magnitude = 1527.872814217052
# Applied force vector = [ 900.         1200.          286.50866911]
# Applied force magnitude = 1527.1172900183876
# Applied force vector = [ 900.         1200.          282.46034218]
# Applied force magnitude = 1526.3629466497628
# Applied force vector = [ 900.        1200.         278.3638335]
# Applied force magnitude = 1525.6101808140356
# Applied force vector = [ 900.         1200.          274.21920343]
# Applied force magnitude = 1524.8593940196415
# Applied force vector = [ 900.         1200.          270.02651286]
# Applied force magnitude = 1524.110992560842
# Applied force vector = [ 900.         1200.          265.78582322]
# Applied force magnitude = 1523.3653874965632
# Applied force vector = [ 900.         1200.          261.49719648]
# Applied force magnitude = 1522.6229946277783
# Applied force vector = [ 900.         1200.          257.16069517]
# Applied force magnitude = 1521.8842344733873
# Applied force vector = [ 900.        1200.         252.7763823]
# Applied force magnitude = 1521.14953224455
# Applied force vector = [ 900.         1200.          248.34432144]
# Applied force magnitude = 1520.419317817422
# Applied force vector = [ 900.         1200.          243.86457668]
# Applied force magnitude = 1519.694025704253
# Applied force vector = [ 900.         1200.          239.33721263]
# Applied force magnitude = 1518.974095022793
# Applied force vector = [ 900.         1200.          234.76229441]
# Applied force magnitude = 1518.259969463969
# Applied force vector = [ 900.         1200.          230.13988766]
# Applied force magnitude = 1517.552097257775
# Applied force vector = [ 900.         1200.          225.47005853]
# Applied force magnitude = 1516.8509311373405
# Applied force vector = [ 900.         1200.          220.75287367]
# Applied force magnitude = 1516.1569283011202
# Applied force vector = [ 900.         1200.          215.98840026]
# Applied force magnitude = 1515.470550373164
# Applied force vector = [ 900.         1200.          211.17670596]
# Applied force magnitude = 1514.7922633614232
# Applied force vector = [ 900.         1200.          206.31785892]
# Applied force magnitude = 1514.1225376140408
# Applied force vector = [ 900.         1200.          201.41192782]
# Applied force magnitude = 1513.4618477735864
# Applied force vector = [ 900.         1200.          196.45898178]
# Applied force magnitude = 1512.8106727291906
# Applied force vector = [ 900.         1200.          191.45909047]
# Applied force magnitude = 1512.1694955665284
# Applied force vector = [ 900.         1200.          186.41232398]
# Applied force magnitude = 1511.5388035156163
# Applied force vector = [ 900.         1200.          181.31875295]
# Applied force magnitude = 1510.9190878963761
# Applied force vector = [ 900.         1200.          176.17844843]
# Applied force magnitude = 1510.3108440619226
# Applied force vector = [ 900.       1200.        170.991482]
# Applied force magnitude = 1509.7145713395362
# Applied force vector = [ 900.         1200.          165.75792567]
# Applied force magnitude = 1509.1307729692792
# Applied force vector = [ 900.         1200.          160.47785195]
# Applied force magnitude = 1508.5599560402186
# Applied force vector = [ 900.         1200.          155.15133381]
# Applied force magnitude = 1508.0026314242145
# Applied force vector = [ 900.         1200.          149.77844465]
# Applied force magnitude = 1507.4593137072404
# Applied force vector = [ 900.         1200.          144.35925837]
# Applied force magnitude = 1506.9305211182002
# Applied force vector = [ 900.        1200.         138.8938493]
# Applied force magnitude = 1506.416775455206
# Applied force vector = [ 900.         1200.          133.38229222]
# Applied force magnitude = 1505.9186020092895
# Applied force vector = [ 900.         1200.          127.82466237]
# Applied force magnitude = 1505.4365294855122
# Applied force vector = [ 900.         1200.          122.22103542]
# Applied force magnitude = 1504.971089921448
# Applied force vector = [ 900.        1200.         116.5714875]
# Applied force magnitude = 1504.5228186030147
# Applied force vector = [ 900.         1200.          110.87609515]
# Applied force magnitude = 1504.0922539776245
# Applied force vector = [ 900.         1200.          105.13493537]
# Applied force magnitude = 1503.679937564639
# Applied force vector = [ 900.         1200.           99.34808556]
# Applied force magnitude = 1503.286413863102
# Applied force vector = [ 900.         1200.           93.51562359]
# Applied force magnitude = 1502.9122302567375
# Applied force vector = [ 900.         1200.           87.63762771]
# Applied force magnitude = 1502.5579369161976
# Applied force vector = [ 900.        1200.          81.7141766]
# Applied force magnitude = 1502.2240866985467
# Applied force vector = [ 900.         1200.           75.74534937]
# Applied force magnitude = 1501.9112350439768
# Applied force vector = [ 900.         1200.           69.73122553]
# Applied force magnitude = 1501.6199398697427
# Applied force vector = [ 900.         1200.           63.67188501]
# Applied force magnitude = 1501.3507614613186
# Applied force vector = [ 900.         1200.           57.56740812]
# Applied force magnitude = 1501.1042623607734
# Applied force vector = [ 900.        1200.          51.4178756]
# Applied force magnitude = 1500.8810072523706
# Applied force vector = [ 900.         1200.           45.22336856]
# Applied force magnitude = 1500.681562845396
# Applied force vector = [ 900.         1200.           38.98396853]
# Applied force magnitude = 1500.5064977542281
# Applied force vector = [ 900.         1200.           32.69975742]
# Applied force magnitude = 1500.356382375661
# Applied force vector = [ 900.         1200.           26.37081752]
# Applied force magnitude = 1500.2317887634995
# Applied force vector = [ 900.        1200.          19.9972315]
# Applied force magnitude = 1500.133290500448
# Applied force vector = [ 900.         1200.           13.57908243]
# Applied force magnitude = 1500.0614625673186
# Applied force vector = [ 900.         1200.            7.11645373]
# Applied force magnitude = 1500.0168812095847
# Applied force vector = [9.00000000e+02 1.20000000e+03 6.09429217e-01]
# Applied force magnitude = 1500.0001238013185
# Applied force vector = [ 900.         1200.           -5.94190695]
# Applied force magnitude = 1500.0117687065472
# Applied force vector = [ 900.         1200.           -5.46679439]
# Applied force magnitude = 1500.0099619138855
# Applied force vector = [ 900.         1200.           -5.02969084]
# Applied force magnitude = 1500.0084325729401
# Applied force vector = [ 900.         1200.           -4.62755557]
# Applied force magnitude = 1500.0071380732043
# Applied force vector = [ 900.         1200.           -4.25759113]
# Applied force magnitude = 1500.0060423485609
# Applied force vector = [ 900.         1200.           -3.91722384]
# Applied force magnitude = 1500.0051148721384
# Applied force vector = [ 900.         1200.           -3.60408593]
# Applied force magnitude = 1500.0043298055448
# Applied force vector = [ 900.         1200.           -3.31599905]
# Applied force magnitude = 1500.0036652787649
# Applied force vector = [ 900.         1200.           -3.05095913]
# Applied force magnitude = 1500.003102780662
# Applied force vector = [ 900.        1200.          -2.8071224]
# Applied force magnitude = 1500.0026266430891
# Applied force vector = [ 900.         1200.           -2.58279261]
# Applied force magnitude = 1500.0022236042366
# Applied force vector = [ 900.        1200.          -2.3764092]
# Applied force magnitude = 1500.0018824390459
# Applied force vector = [ 900.         1200.           -2.18653646]
# Applied force magnitude = 1500.0015936463883
# Applied force vector = [ 900.         1200.           -2.01185355]
# Applied force magnitude = 1500.0013491842901
# Applied force vector = [ 900.         1200.           -1.85114526]
# Applied force magnitude = 1500.0011422458258
# Applied force vector = [ 900.         1200.           -1.70329364]
# Applied force magnitude = 1500.0009670694312
# Applied force vector = [ 900.         1200.           -1.56727015]
# Applied force magnitude = 1500.000818778351
# Applied force vector = [ 900.         1200.           -1.44212854]
# Applied force magnitude = 1500.0006932447466
# Applied force vector = [ 900.         1200.           -1.32699826]
# Applied force magnitude = 1500.0005869746747
# Applied force vector = [ 900.         1200.           -1.22107839]
# Applied force magnitude = 1500.000497010733
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.12363212e+00]
# Applied force magnitude = 1500.0004208496568
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.03398155e+00]
# Applied force magnitude = 1500.0003563725752
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -9.51503029e-01]
# Applied force magnitude = 1500.0003017859744
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -8.75622787e-01]
# Applied force magnitude = 1500.000255571733
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -8.05812964e-01]
# Applied force magnitude = 1500.0002164448285
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -7.41587927e-01]
# Applied force magnitude = 1500.0001833175397
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -6.82500892e-01]
# Applied force magnitude = 1500.000155269148
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -6.28140821e-01]
# Applied force magnitude = 1500.0001315202912
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -5.78129555e-01]
# Applied force magnitude = 1500.0001114112567
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -5.32119191e-01]
# Applied force magnitude = 1500.0000943836083
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -4.89789656e-01]
# Applied force magnitude = 1500.0000799646334
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -4.50846483e-01]
# Applied force magnitude = 1500.0000677541823
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -4.15018765e-01]
# Applied force magnitude = 1500.0000574135238
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.82057263e-01]
# Applied force magnitude = 1500.0000486559168
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.51732682e-01]
# Applied force magnitude = 1500.000041238626
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.23834068e-01]
# Applied force magnitude = 1500.0000349561674
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -2.98167342e-01]
# Applied force magnitude = 1500.0000296345877
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -2.74553955e-01]
# Applied force magnitude = 1500.0000251266245
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -2.52829639e-01]
# Applied force magnitude = 1500.0000213076087
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -2.32843267e-01]
# Applied force magnitude = 1500.0000180719956
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -2.14455806e-01]
# Applied force magnitude = 1500.0000153304309
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.97539342e-01]
# Applied force magnitude = 1500.0000130072638
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.81976194e-01]
# Applied force magnitude = 1500.000011038445
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.67658099e-01]
# Applied force magnitude = 1500.000009369746
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.54485451e-01]
# Applied force magnitude = 1500.0000079552515
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.42366615e-01]
# Applied force magnitude = 1500.0000067560843
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.31217286e-01]
# Applied force magnitude = 1500.0000057393254
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.20959903e-01]
# Applied force magnitude = 1500.0000048770994
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.11523111e-01]
# Applied force magnitude = 1500.0000041458013
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.02841262e-01]
# Applied force magnitude = 1500.0000035254416
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -9.48539607e-02]
# Applied force magnitude = 1500.0000029990913
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -8.75056439e-02]
# Applied force magnitude = 1500.0000025524125
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -8.07451924e-02]
# Applied force magnitude = 1500.000002173262
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -7.4525577e-02]
# Applied force magnitude = 1500.000001851354
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -6.88035308e-02]
# Applied force magnitude = 1500.0000015779751
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -6.35392484e-02]
# Applied force magnitude = 1500.0000013457452
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -5.86961085e-02]
# Applied force magnitude = 1500.000001148411
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -5.42404198e-02]
# Applied force magnitude = 1500.0000009806745
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -5.01411862e-02]
# Applied force magnitude = 1500.0000008380462
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -4.63698913e-02]
# Applied force magnitude = 1500.0000007167223
# Applied force vector = [ 9.00000e+02  1.20000e+03 -4.29003e-02]
# Applied force magnitude = 1500.0000006134787
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.9708276e-02]
# Applied force magnitude = 1500.0000005255824
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.67716139e-02]
# Applied force magnitude = 1500.0000004507172
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.40698848e-02]
# Applied force magnitude = 1500.000000386919
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.1584294e-02]
# Applied force magnitude = 1500.0000003325224
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -2.92975505e-02]
# Applied force magnitude = 1500.0000002861154
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -2.71937465e-02]
# Applied force magnitude = 1500.0000002465
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -2.52582468e-02]
# Applied force magnitude = 1500.0000002126596
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -2.3477587e-02]
# Applied force magnitude = 1500.0000001837325
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -2.18393801e-02]
# Applied force magnitude = 1500.0000001589863
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -2.03322296e-02]
# Applied force magnitude = 1500.0000001377998
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.89456513e-02]
# Applied force magnitude = 1500.0000001196458
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.76699992e-02]
# Applied force magnitude = 1500.0000001040762
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.64963992e-02]
# Applied force magnitude = 1500.0000000907103
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.54166873e-02]
# Applied force magnitude = 1500.0000000792247
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.44233523e-02]
# Applied force magnitude = 1500.0000000693444
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.35094841e-02]
# Applied force magnitude = 1500.0000000608354
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.26687254e-02]
# Applied force magnitude = 1500.000000053499
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.18952274e-02]
# Applied force magnitude = 1500.0000000471655
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.11836092e-02]
# Applied force magnitude = 1500.000000041691
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -1.05289204e-02]
# Applied force magnitude = 1500.0000000369528
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -9.92660681e-03]
# Applied force magnitude = 1500.000000032846
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -9.37247826e-03]
# Applied force magnitude = 1500.0000000292812
# Applied force vector = [ 9.00000e+02  1.20000e+03 -8.86268e-03]
# Applied force magnitude = 1500.0000000261825
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -8.3936656e-03]
# Applied force magnitude = 1500.0000000234845
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -7.96217236e-03]
# Applied force magnitude = 1500.000000021132
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -7.56519857e-03]
# Applied force magnitude = 1500.0000000190773
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -7.19998268e-03]
# Applied force magnitude = 1500.00000001728
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -6.86398407e-03]
# Applied force magnitude = 1500.0000000157047
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -6.55486534e-03]
# Applied force magnitude = 1500.000000014322
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -6.27047611e-03]
# Applied force magnitude = 1500.0000000131063
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -6.00883803e-03]
# Applied force magnitude = 1500.0000000120353
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -5.76813098e-03]
# Applied force magnitude = 1500.0000000110906
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -5.5466805e-03]
# Applied force magnitude = 1500.0000000102552
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -5.34294606e-03]
# Applied force magnitude = 1500.0000000095156
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -5.15551038e-03]
# Applied force magnitude = 1500.0000000088598
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -4.98306955e-03]
# Applied force magnitude = 1500.000000008277
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -4.82442398e-03]
# Applied force magnitude = 1500.0000000077584
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -4.67847007e-03]
# Applied force magnitude = 1500.000000007296
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -4.54419246e-03]
# Applied force magnitude = 1500.0000000068833
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -4.42065706e-03]
# Applied force magnitude = 1500.000000006514
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -4.3070045e-03]
# Applied force magnitude = 1500.0000000061834
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -4.20244414e-03]
# Applied force magnitude = 1500.000000005887
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -4.10624861e-03]
# Applied force magnitude = 1500.0000000056204
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -4.01774872e-03]
# Applied force magnitude = 1500.0000000053808
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.93632882e-03]
# Applied force magnitude = 1500.000000005165
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.86142252e-03]
# Applied force magnitude = 1500.0000000049702
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.79250871e-03]
# Applied force magnitude = 1500.0000000047944
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.72910802e-03]
# Applied force magnitude = 1500.0000000046352
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.67077938e-03]
# Applied force magnitude = 1500.0000000044915
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.61711703e-03]
# Applied force magnitude = 1500.0000000043613
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.56774766e-03]
# Applied force magnitude = 1500.000000004243
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.52232785e-03]
# Applied force magnitude = 1500.0000000041355
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.48054162e-03]
# Applied force magnitude = 1500.0000000040382
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.44209829e-03]
# Applied force magnitude = 1500.0000000039493
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.40673043e-03]
# Applied force magnitude = 1500.0000000038685
# Applied force vector = [ 9.000000e+02  1.200000e+03 -3.374192e-03]
# Applied force magnitude = 1500.000000003795
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.34425664e-03]
# Applied force magnitude = 1500.000000003728
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.3167161e-03]
# Applied force magnitude = 1500.0000000036669
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.29137882e-03]
# Applied force magnitude = 1500.0000000036111
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.26806851e-03]
# Applied force magnitude = 1500.0000000035602
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.24662303e-03]
# Applied force magnitude = 1500.0000000035136
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.22689319e-03]
# Applied force magnitude = 1500.0000000034709
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.20874173e-03]
# Applied force magnitude = 1500.000000003432
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.19204239e-03]
# Applied force magnitude = 1500.0000000033963
# Applied force vector = [ 9.000000e+02  1.200000e+03 -3.176679e-03]
# Applied force magnitude = 1500.0000000033638
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.16254468e-03]
# Applied force magnitude = 1500.0000000033338
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.14954111e-03]
# Applied force magnitude = 1500.0000000033065
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.13757782e-03]
# Applied force magnitude = 1500.0000000032815
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.12657159e-03]
# Applied force magnitude = 1500.0000000032585
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.11644587e-03]
# Applied force magnitude = 1500.0000000032373
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.1071302e-03]
# Applied force magnitude = 1500.000000003218
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.09855978e-03]
# Applied force magnitude = 1500.0000000032003
# Applied force vector = [ 9.000000e+02  1.200000e+03 -3.090675e-03]
# Applied force magnitude = 1500.0000000031841
# Applied force vector = [ 9.000000e+02  1.200000e+03 -3.083421e-03]
# Applied force magnitude = 1500.0000000031691
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.07674732e-03]
# Applied force magnitude = 1500.0000000031555
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.07060753e-03]
# Applied force magnitude = 1500.000000003143
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.06495893e-03]
# Applied force magnitude = 1500.0000000031312
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.05976222e-03]
# Applied force magnitude = 1500.0000000031207
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.05498124e-03]
# Applied force magnitude = 1500.000000003111
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.05058274e-03]
# Applied force magnitude = 1500.000000003102
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.04653612e-03]
# Applied force magnitude = 1500.0000000030939
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.04281323e-03]
# Applied force magnitude = 1500.0000000030861
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.03938817e-03]
# Applied force magnitude = 1500.0000000030793
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.03623712e-03]
# Applied force magnitude = 1500.000000003073
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.03333815e-03]
# Applied force magnitude = 1500.000000003067
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0306711e-03]
# Applied force magnitude = 1500.0000000030618
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.02821741e-03]
# Applied force magnitude = 1500.0000000030568
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.02596002e-03]
# Applied force magnitude = 1500.000000003052
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.02388322e-03]
# Applied force magnitude = 1500.000000003048
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.02197256e-03]
# Applied force magnitude = 1500.000000003044
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.02021475e-03]
# Applied force magnitude = 1500.0000000030407
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.01859757e-03]
# Applied force magnitude = 1500.0000000030373
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.01710977e-03]
# Applied force magnitude = 1500.0000000030343
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.01574099e-03]
# Applied force magnitude = 1500.0000000030316
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.01448171e-03]
# Applied force magnitude = 1500.000000003029
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.01332317e-03]
# Applied force magnitude = 1500.0000000030266
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.01225732e-03]
# Applied force magnitude = 1500.0000000030245
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.01127673e-03]
# Applied force magnitude = 1500.0000000030227
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.01037459e-03]
# Applied force magnitude = 1500.0000000030207
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00954463e-03]
# Applied force magnitude = 1500.0000000030193
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00878106e-03]
# Applied force magnitude = 1500.0000000030177
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00807857e-03]
# Applied force magnitude = 1500.0000000030163
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00743229e-03]
# Applied force magnitude = 1500.0000000030147
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0068377e-03]
# Applied force magnitude = 1500.0000000030138
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00629069e-03]
# Applied force magnitude = 1500.0000000030125
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00578743e-03]
# Applied force magnitude = 1500.0000000030116
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00532444e-03]
# Applied force magnitude = 1500.0000000030107
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00489848e-03]
# Applied force magnitude = 1500.00000000301
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0045066e-03]
# Applied force magnitude = 1500.0000000030088
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00414608e-03]
# Applied force magnitude = 1500.0000000030084
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00381439e-03]
# Applied force magnitude = 1500.0000000030077
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00350924e-03]
# Applied force magnitude = 1500.000000003007
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0032285e-03]
# Applied force magnitude = 1500.0000000030066
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00297022e-03]
# Applied force magnitude = 1500.000000003006
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0027326e-03]
# Applied force magnitude = 1500.0000000030054
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00251399e-03]
# Applied force magnitude = 1500.000000003005
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00231287e-03]
# Applied force magnitude = 1500.0000000030045
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00212784e-03]
# Applied force magnitude = 1500.0000000030043
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00195762e-03]
# Applied force magnitude = 1500.000000003004
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00180101e-03]
# Applied force magnitude = 1500.0000000030036
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00165693e-03]
# Applied force magnitude = 1500.0000000030034
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00152437e-03]
# Applied force magnitude = 1500.0000000030032
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00140242e-03]
# Applied force magnitude = 1500.0000000030027
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00129023e-03]
# Applied force magnitude = 1500.0000000030027
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00118701e-03]
# Applied force magnitude = 1500.0000000030025
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00109205e-03]
# Applied force magnitude = 1500.000000003002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00100469e-03]
# Applied force magnitude = 1500.000000003002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00092431e-03]
# Applied force magnitude = 1500.0000000030018
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00085037e-03]
# Applied force magnitude = 1500.0000000030016
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00078234e-03]
# Applied force magnitude = 1500.0000000030016
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00071975e-03]
# Applied force magnitude = 1500.0000000030016
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00066217e-03]
# Applied force magnitude = 1500.0000000030013
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0006092e-03]
# Applied force magnitude = 1500.000000003001
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00056046e-03]
# Applied force magnitude = 1500.000000003001
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00051562e-03]
# Applied force magnitude = 1500.000000003001
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00047437e-03]
# Applied force magnitude = 1500.0000000030009
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00043642e-03]
# Applied force magnitude = 1500.0000000030009
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00040151e-03]
# Applied force magnitude = 1500.0000000030009
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00036939e-03]
# Applied force magnitude = 1500.0000000030007
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00033984e-03]
# Applied force magnitude = 1500.0000000030007
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00031265e-03]
# Applied force magnitude = 1500.0000000030007
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00028764e-03]
# Applied force magnitude = 1500.0000000030007
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00026463e-03]
# Applied force magnitude = 1500.0000000030007
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00024346e-03]
# Applied force magnitude = 1500.0000000030004
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00022398e-03]
# Applied force magnitude = 1500.0000000030004
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00020606e-03]
# Applied force magnitude = 1500.0000000030004
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00018958e-03]
# Applied force magnitude = 1500.0000000030004
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00017441e-03]
# Applied force magnitude = 1500.0000000030004
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00016046e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00014762e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00013581e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00012495e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00011495e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00010576e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00009729e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00008951e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00008235e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00007576e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0000697e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00006413e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.000000e+02  1.200000e+03 -3.000059e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00005428e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00004993e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00004594e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00004226e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00003888e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00003577e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00003291e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00003028e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00002786e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00002563e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00002358e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00002169e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00001996e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00001836e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00001689e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00001554e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0000143e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00001315e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0000121e-03]
# Applied force magnitude = 1500.0000000030002
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00001113e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00001024e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000942e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000867e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000798e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000734e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000675e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000621e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000571e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000526e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000484e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000445e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000409e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000377e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000346e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000319e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000293e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0000027e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000248e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000228e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0000021e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000193e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000178e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000164e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0000015e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000138e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000127e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000117e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000108e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000099e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000091e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000084e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000077e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000071e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000065e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0000006e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000055e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000051e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000047e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000043e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0000000e+02  1.2000000e+03 -3.0000004e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000036e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.00000000e+02  1.20000000e+03 -3.00000034e-03]
# Applied force magnitude = 1500.000000003
# ...
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
# Applied force vector = [ 9.0e+02  1.2e+03 -3.0e-03]
# Applied force magnitude = 1500.000000003
